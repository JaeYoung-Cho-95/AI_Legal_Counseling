# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import os

# %%
path = 'D:/Programming/2020.11.AIcompet'

# https://systemtrade.tistory.com/345 << bs 사용법

# %%
driver = webdriver.Ie('D:/Programming/IEDriverServer2.exe')
time.sleep(1)
driver.get('https://www.scourt.go.kr/portal/information/finalruling/peruse/peruse_status.jsp')
time.sleep(1)

iframes = driver.find_elements_by_tag_name('iframe')
print('현재 페이지에 iframe은 %d개가 있습니다.' % len(iframes))
driver.switch_to.frame(iframes[0])

driver.find_element_by_xpath('''//input[@id='accept']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='name']''').send_keys('박동주')
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='jumin1']''').send_keys('951030')
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='jumin2']''').send_keys('1126827')
time.sleep(1)
driver.find_element_by_xpath('''//img[@id='auth']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//a[@id='tb2']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//img[@id='endDayBtn']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='eDate']''').send_keys('20161114')
time.sleep(1)
driver.find_element_by_xpath('''//img[@id='startDayBtn']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='sDate']''').send_keys('20141115')
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='mq']''').send_keys('폭행 | 폭력')
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='msearch-button']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//select[@id='viewlist']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//select[@id='viewlist']/option[@value='50']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//dd[@class='btn']/img[@onclick='view()']''').click()
time.sleep(1)

soup = BeautifulSoup(driver.page_source, 'html.parser')
alist = []
blist = []

for n,i in enumerate(soup.find_all('td')):
    j = i.get_text()
    j = " ".join(j.split())
    alist.append(j)
    if ((n+1) % 6) == 0:
        blist.append(alist)
        alist = []

num = 2

while num < 83:
    
    path = '''//a[@onclick="javascript:mdetail_search('{}');"]'''.format(num)
    
    if driver.find_element_by_xpath(path):
        driver.find_element_by_xpath(path).click()
        time.sleep(1)
        soup = BeautifulSoup(driver.page_source, 'html.parser')

        if soup.find('tr',{'class':'disable2'}):
            soup.find('tr',{'class':'disable2'}).decompose()

        for n,i in enumerate(soup.find_all('td')):
            j = i.get_text()
            j = " ".join(j.split())
            alist.append(j)
            if ((n+1) % 6) == 0:
                blist.append(alist)
                alist = []
        num = num + 1
        
    else:
        continue
    
df = pd.DataFrame(blist)
time.sleep(3)
print('완료')
driver.quit()
# Out:
# 현재 페이지에 iframe은 1개가 있습니다.
# 완료

# %%
df[480:520]
# Out:
#     0           1                           2              3  \
# 480    2016.09.23  인천지방법원 부천지원 [2016가단104694]  손해배상(기···[민사]
# 481    2016.09.23        서울행정법원 [2015구합77271]  부당해고구제···[행정]
# 482    2016.09.23        서울행정법원 [2015구합75312]  유족급여및장···[행정]
# 483    2016.09.23        서울행정법원 [2015구합73729]  유족보상금 ···[행정]
# 484    2016.09.23        서울행정법원 [2015구단54745]  공무상요양불···[행정]
# 485    2016.09.23         수원지방법원 [2015구단3694]  국가유공자요···[행정]
# 486    2016.09.23       서울고등법원 [2015나2040959]  손해배상(기···[민사]
# 487    2016.09.23       서울중앙지방법원 [2015나60244]  손해배상(기···[민사]
# 488    2016.09.23         부산지방법원 [2015나41135]        구상금[민사]
# 489    2016.09.23     서울남부지방법원 [2015가단218888]  유류분반환 ···[민사]
# 490    2016.09.23        대구지방법원 [2015가단48822]       물품대금[민사]
# 491    2016.09.23   창원지방법원 진주지원 [2015가단34716]  손해배상(기···[민사]
# 492    2016.09.22       대전지방법원 [2016구합100064]     감봉처분취소[행정]
# 493    2016.09.22        서울행정법원 [2016구합56592]  정보공개거부···[행정]
# 494    2016.09.22        부산지방법원 [2016구합21344]  난민불인정결···[행정]
. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
#
#                                                   이유
# 0  ... 문제에 대해 이야기하던 중 위 사촌으로부터 폭행을 당하였고, 원고도 이에 격...
# 1  ... 있는 무슬림 공동체 B의 조직원들로부터 폭행을 당하였고 살해하겠다는 위협을 ...
# 2  ... 가. 원고의 주장 원고는 동성애자인 친구가 폭행당하는 것에 대항하여 친구를 ...
# 3  ... 2012년 여름에 처남 등 다수의 사람들로부터 폭행을 당하여 다른 지역으로 ...
# 4  ... 이후 2010. 8월경부터 새아버지로부터 폭행과 학대를 받고 있으므로, 난민...

# %%
df.to_csv('law_crawling50.csv', sep=',', na_rep='NaN', encoding='utf-8')

# %%
tq = pd.read_csv("D:/Programming/2020.11.AIcompet/law_crawling51.csv", sep=",", encoding="CP949")
tq
# Out:
#       Unnamed: 0   0           1                     2              3  \
# 0              0 NaN  2016.11.11   대구지방법원 [2016구합1174]  난민불인정처···[행정]
# 1              1 NaN  2016.11.11  서울행정법원 [2016구단59822]  난민불인정결···[행정]
# 2              2 NaN  2016.11.11  서울행정법원 [2016구단26143]  난민불인정결···[행정]
# 3              3 NaN  2016.11.11  서울행정법원 [2016구단24758]  난민불인정결···[행정]
# 4              4 NaN  2016.11.11  서울행정법원 [2016구단23502]  난민불인정결···[행정]
# ...          ...  ..         ...                   ...            ...
# 4095        4095 NaN  2015.04.17   제주지방법원 [2013가단7225]  손해배상(기···[민사]
# 4096        4096 NaN  2015.04.16    대구지방법원 [2015가합483]  손해배상(기···[민사]
# 4097        4097 NaN  2015.04.16  서울행정법원 [2014구합53056]     해임처분취소[행정]
# 4098        4098 NaN  2015.04.16  서울행정법원 [2014구합22281]  난민불인정결···[행정]
# 4099        4099 NaN  2015.04.16  서울행정법원 [2014구합20575]  난민불인정결···[행정]
#
#                                                       4  \
# 0                   1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 1                   1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 2                   1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 3                   1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 4                   1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# ...                                                 ...
# 4095  1. 피고 B, C, D, E은 공동하여 원고(선정당사자)에게 2,000,000원,...
# 4096  1. 피고는, 가. 원고 A에게 2,000,000원 및 이에 대하여 2012. 3....
# 4097                      원고의 청구를 기각한다. 소송비용은 원고가 부담한다.
# 4098                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 4099                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
#
#                                                       5
# 0     ... 문제에 대해 이야기하던 중 위 사촌으로부터 폭행을 당하였고, 원고도 이에 격...
# 1     ... 있는 무슬림 공동체 B의 조직원들로부터 폭행을 당하였고 살해하겠다는 위협을 ...
# 2     ... 가. 원고의 주장 원고는 동성애자인 친구가 폭행당하는 것에 대항하여 친구를 ...
# 3     ... 2012년 여름에 처남 등 다수의 사람들로부터 폭행을 당하여 다른 지역으로 ...
# 4     ... 이후 2010. 8월경부터 새아버지로부터 폭행과 학대를 받고 있으므로, 난민...
# ...                                                 ...
# 4095  ..., 번갈아가며 N을 폭행하던 중, 피고 E은... 사회에는 학교 내 폭력과 집...
# 4096  ... 위와 같이 원고 A를 폭행하였다는 범죄사실로... 기소되어 성폭력... 더보...
# 4097  ... 치료를 받게 된 것으로 이를 상해 또는 폭행으로 보기는 어렵다. 다) 제3징...
# 4098  ..., 이하 ‘PML-N'이라고 한다) 정당원들로부터 폭행을 당하였다. 따라서 원...
# 4099  ... 위해 거짓말을 하자 어머니와 처에게 폭행을 가하였다. 이에 원고가 화가 나 ...
#
# [4100 rows x 7 columns]
