# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import nltk

# %%
from konlpy.tag import Okt
from konlpy.tag import Kkma
from konlpy.utils import pprint
from konlpy.corpus import kolaw
from nltk import collocations

# http://kkma.snu.ac.kr/documents/?doc=postag << 한글 형태소 품사 태그표
# https://wikidocs.net/21698 << 자연어처리 참고 블로그
# https://konlpy.org/en/latest/api/konlpy.tag/ << okt, mecab
# https://cyc1am3n.github.io/2018/11/10/classifying_korean_movie_review.html << konlpy 로 감정분석

# %%
kkma = Kkma()
okt = Okt()

print(okt.pos('이 밤 그날의 반딧불을 당신의 창 가까이 보낼게요'))
print(kkma.pos('이 밤 그날의 반딧불을 당신의 창 가까이 보낼게요'))
# Out:
# [('이', 'Noun'), ('밤', 'Noun'), ('그날', 'Noun'), ('의', 'Josa'), ('반딧불', 'Noun'), ('을', 'Josa'), ('당신', 'Noun'), ('의', 'Josa'), ('창', 'Noun'), ('가까이', 'Noun'), ('보낼게요', 'Verb')]
# [('이', 'MDT'), ('밤', 'NNG'), ('그날', 'NNG'), ('의', 'JKG'), ('반딧불', 'NNG'), ('을', 'JKO'), ('당신', 'NP'), ('의', 'JKG'), ('창', 'NNG'), ('가까이', 'MAG'), ('보내', 'VV'), ('ㄹ게요', 'EFN')]

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
plt.rc('font', family='NanumGothic')
# %matplotlib inline

# %%
law_df = pd.read_csv('D:/Programming/2020.11.AIcompet/law_preprocessing2.csv', sep=',', encoding='CP949')
law_df = law_df.drop(columns='Unnamed: 0')
law_df
# Out:
#              선고일자  법원명            사건명  \
# 0      2015.04.16    0  난민불인정결···[행정]
# 1      2015.04.16    0  난민불인정결···[행정]
# 2      2015.04.16    0     해임처분취소[행정]
# 3      2015.04.16    1  손해배상(기···[민사]
# 4      2015.04.17    0  난민불인정결···[행정]
# ...           ...  ...            ...
# 12285  2020.10.08    3  난민불인정결···[행정]
# 12286  2020.10.14    1  명의이전등록···[민사]
# 12287  2020.10.14    8  손해배상(기···[민사]
# 12288  2020.10.14   20       급여지급[민사]
# 12289  2020.10.15   23  부당징계및부···[행정]
#
#                                                       주문  \
# 0                    1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 1                    1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 2                          원고의 청구를 기각한다. 소송비용은 원고가 부담한다.
# 3      1. 피고는, 가. 원고 A에게 2,000,000원 및 이에 대하여 2012. 3....
# 4                    1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# ...                                                  ...
# 12285                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 12286  1. 피고는 원고에게, 가. 별지 목록 기재 자동차에 관하여 구미시 차량등록사업소 ...
# 12287  1. 당심에서 확장된 원고의 청구에 따라 제1심판결의 주문 제1, 2항을 다음과 같...
# 12288  피고는 원고에게 58,580,000원과 이에 대한 2019. 2. 14.부터 202...
# 12289  상고를 모두 기각한다. 상고비용 중 피고의 상고로 인한 부분은 피고가, 피고 보조참...
#
#                                                       이유  승소여부  \
# 0      ... 위해 거짓말을 하자 어머니와 처에게 폭행을 가하였다. 이에 원고가 화가 나 ...     0
# 1      ..., 이하 ‘PML-N'이라고 한다) 정당원들로부터 폭행을 당하였다. 따라서 원...     0
# 2      ... 치료를 받게 된 것으로 이를 상해 또는 폭행으로 보기는 어렵다. 다) 제3징...     0
# 3      ... 위와 같이 원고 A를 폭행하였다는 범죄사실로... 기소되어 성폭력... 더보...     1
# 4      ... 길에 성명불상의 4명의 남성들로부터 폭행 및 협박을 당하였다. 위 남성들을 ...     0
# ...                                                  ...   ...
# 12285  ... 하였는데, 위 가해자가 사람을 보내 원고를 폭행하고 신고를 취하하라고 협박하...     0
# 12286  ... 항의하였고 이로 인하여 피고로부터 폭행을 당하였다고 진술하였으며, 이 사건....     1
# 12287  ... 한 사실이 인정되고, 이러한 사정이 피고의 폭행을 유발하였다고 보인다. 이와...     1
# 12288  ... 학생들을 상대로 실시된 학교폭력(성폭력) 피해에 대한 설문조사 결과, ‘어깨...     1
# 12289  ... 원고 F, G가 ‘순환전보 관련 사업소장 폭행’ 행위를 했다는 이유로 징계를...     0
#
#                                                    이유토큰화
# 0      [('...', 'Punctuation'), ('위해', 'Noun'), ('거짓말...
# 1      [('...,', 'Punctuation'), ('이하', 'Noun'), ('‘'...
# 2      [('...', 'Punctuation'), ('치료', 'Noun'), ('를',...
# 3      [('...', 'Punctuation'), ('위', 'Noun'), ('와', ...
# 4      [('...', 'Punctuation'), ('길', 'Noun'), ('에', ...
# ...                                                  ...
# 12285  [('...', 'Punctuation'), ('하였는데', 'Verb'), (',...
# 12286  [('...', 'Punctuation'), ('항의', 'Noun'), ('하였고...
# 12287  [('...', 'Punctuation'), ('한', 'Verb'), ('사실',...
# 12288  [('...', 'Punctuation'), ('학생', 'Noun'), ('들',...
# 12289  [('...', 'Punctuation'), ('원고', 'Noun'), ('F',...
#
# [12290 rows x 7 columns]

# %%
# 승소여부를 판단할 수 있는 주문 feature에는 '기각','각하' 등등 패소 여부를 알 수 있는 단어들이 있다.
# 우선 '기각','각하'를 기준으로 승소 여부를 판단

temp1 = law_df['주문']
temp2 = []
for morp in temp1:
    if ('기각' in morp) or ('각하' in morp):
        temp2.append(0)
    else:
        temp2.append(1)

print(temp2[:10])
print(len(temp2))
# Out:
# [0, 0, 0, 1, 0, 0, 0, 0, 0, 1]
# 12290

# %%
law_df['승소여부'] = temp2
law_df.head()
# Out:
#          선고일자  법원명            사건명  \
# 0  2015.04.16    0  난민불인정결···[행정]
# 1  2015.04.16    0  난민불인정결···[행정]
# 2  2015.04.16    0     해임처분취소[행정]
# 3  2015.04.16    1  손해배상(기···[민사]
# 4  2015.04.17    0  난민불인정결···[행정]
#
#                                                   주문  \
# 0                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 1                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 2                      원고의 청구를 기각한다. 소송비용은 원고가 부담한다.
# 3  1. 피고는, 가. 원고 A에게 2,000,000원 및 이에 대하여 2012. 3....
# 4                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
#
#                                                   이유  승소여부  \
# 0  ... 위해 거짓말을 하자 어머니와 처에게 폭행을 가하였다. 이에 원고가 화가 나 ...     0
# 1  ..., 이하 ‘PML-N'이라고 한다) 정당원들로부터 폭행을 당하였다. 따라서 원...     0
# 2  ... 치료를 받게 된 것으로 이를 상해 또는 폭행으로 보기는 어렵다. 다) 제3징...     0
# 3  ... 위와 같이 원고 A를 폭행하였다는 범죄사실로... 기소되어 성폭력... 더보...     1
# 4  ... 길에 성명불상의 4명의 남성들로부터 폭행 및 협박을 당하였다. 위 남성들을 ...     0
#
#                                                이유토큰화
# 0  [('...', 'Punctuation'), ('위해', 'Noun'), ('거짓말...
# 1  [('...,', 'Punctuation'), ('이하', 'Noun'), ('‘'...
# 2  [('...', 'Punctuation'), ('치료', 'Noun'), ('를',...
# 3  [('...', 'Punctuation'), ('위', 'Noun'), ('와', ...
# 4  [('...', 'Punctuation'), ('길', 'Noun'), ('에', ...

# %%
reason = law_df['이유토큰화'].to_list()
tokens = [t for d in reason for t in d]
print(len(tokens))
# Out:
# 85505041

# %%
print(reason[:2])
print(type(reason))

reason = reason.to_list()
print(reason[:2])
print(type(reason))
# Out:
# ["[('...', 'Punctuation'), ('위해', 'Noun'), ('거짓말', 'Noun'), ('을', 'Josa'), ('하자', 'Noun'), ('어머니', 'Noun'), ('와', 'Josa'), ('처', 'Noun'), ('에게', 'Josa'), ('폭행', 'Noun'), ('을', 'Josa'), ('가하였다', 'Verb'), ('.', 'Punctuation'), ('이', 'Noun'), ('에', 'Josa'), ('원고', 'Noun'), ('가', 'Josa'), ('화가', 'Noun'), ('나', 'Noun'), ('칼', 'Noun'), ('을', 'Josa'), ('...', 'Punctuation'), ('더', 'Noun'), ('보기', 'Noun'), ('...', 'Punctuation'), ('이유', 'Noun'), ('로', 'Josa'), ('카메룬', 'Noun'), ('경찰', 'Noun'), ('에', 'Josa'), ('의해', 'Adjective'), ('구속', 'Noun'), ('되었다', 'Verb'), ('.', 'Punctuation'), ('원고', 'Noun'), ('는', 'Josa'), ('삼촌', 'Noun'), ('의', 'Josa'), ('부탁', 'Noun'), ('으로', 'Josa'), ('삼촌', 'Noun'), ('집', 'Noun'), ('에', 'Josa'), ('있던', 'Adjective'), ('반정부', 'Noun'), ('성향', 'Noun'), ('의', 'Josa'), ('책자', 'Noun'), ('를', 'Josa'), ('자신', 'Noun'), ('의', 'Josa'), ('집', 'Noun'), ('에', 'Josa'), ('숨겼는데', 'Verb'), (',', 'Punctuation'), ('이를', 'Verb'), ('이유', 'Noun'), ('로', 'Josa'), ('경찰', 'Noun'), ('에', 'Josa'), ('의해', 'Adjective'), ('체포', 'Noun'), ('당', 'Suffix'), ('한', 'Josa'), ('적', 'Noun'), ('이', 'Josa'), ('있고', 'Adjective'), (',', 'Punctuation'), ('2005', 'Number'), ('.', 'Punctuation'), ('경', 'Noun'), ('삼촌', 'Noun'), ('의', 'Josa'), ('부탁', 'Noun'), ('으로', 'Josa'), ('SCNC', 'Alpha'), ('가입', 'Noun'), ('을', 'Josa'), ('홍보', 'Noun'), ('하는', 'Verb'), ('내용', 'Noun'), ('의', 'Josa'), ('전단지', 'Noun'), ('를', 'Josa'), ('배포', 'Noun'), ('하기도', 'Verb'), ('하였다', 'Verb'), ('.', 'Punctuation'), ('이', 'Noun'), ('와', 'Josa'), ('같이', 'Adverb'), ('카메룬', 'Noun'), ('정부', 'Noun'), ('는', 'Josa'), ('SCNC', 'Alpha'), ('회원', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('체포', 'Noun'), ('하는', 'Verb'), ('등', 'Noun'), ('박해', 'Noun'), ('하고', 'Josa'), ('있는바', 'Adjective'), (',', 'Punctuation'), ('원고', 'Noun'), ('는', 'Josa'), ('SCNC', 'Alpha'), ('회원', 'Noun'), ('이', 'Josa'), ('아님에도', 'Adjective'), ('카메룬', 'Noun'), ('정부', 'Noun'), ('로부터', 'Noun'), ('SCNC', 'Alpha'), ('회원', 'Noun'), ('으로', 'Josa'), ('오인', 'Noun'), ('을', 'Josa'), ('받고', 'Verb'), ('있다', 'Adjective'), ('(', 'Punctuation'), ('이하', 'Noun'), ('’', 'Punctuation'), ('제', 'Noun'), ('1', 'Number'), ('사유', 'Noun'), ('‘', 'Foreign'), ('라고', 'Josa'), ('한다', 'Verb'), (').', 'Punctuation'), ('2', 'Number'), (')', 'Punctuation'), ('2011', 'Number'), ('.', 'Punctuation'), ('5', 'Number'), ('.', 'Punctuation'), ('경', 'Noun'), ('축구장', 'Noun'), ('에서', 'Josa'), ('선거', 'Noun'), ('유세', 'Noun'), ('를', 'Josa'), ('하던', 'Verb'), ('사람과', 'Noun'), ('축구', 'Noun'), ('를', 'Josa'), ('하던', 'Verb'), ('사람', 'Noun'), ('들', 'Suffix'), ('사이', 'Noun'), ('에', 'Josa'), ('다툼', 'Noun'), ('이', 'Josa'), ('생겼는데', 'Verb'), (',', 'Punctuation'), ('원고', 'Noun'), ('는', 'Josa'), ('그', 'Noun'), ('싸움', 'Noun'), ('에', 'Josa'), ('관여', 'Noun'), ('하지', 'Verb'), ('않았었다', 'Verb'), ('.', 'Punctuation'), ('그런데', 'Conjunction'), ('경찰', 'Noun'), ('은', 'Josa'), ('위', 'Noun'), ('폭행', 'Noun'), ('사건', 'Noun'), ('의', 'Josa'), ('용의자', 'Noun'), ('로', 'Josa'), ('원고', 'Noun'), ('를', 'Josa'), ('지목', 'Noun'), ('한', 'Josa'), ('다음', 'Noun'), ('원고', 'Noun'), ('를', 'Josa'), ('체포', 'Noun'), ('하기', 'Verb'), ('위', 'Noun'), ('하여', 'Verb'), ('원고', 'Noun'), ('의', 'Josa'), ('집', 'Noun'), ('에', 'Josa'), ('찾아왔는데', 'Verb'), (',', 'Punctuation'), ('원고', 'Noun'), ('의', 'Josa'), ('어머니', 'Noun'), ('와', 'Josa'), ('처가', 'Noun'), ('원고', 'Noun'), ('를', 'Josa'), ('숨기기', 'Verb'), ('위해', 'Noun'), ('거짓말', 'Noun'), ('을', 'Josa'), ('하자', 'Noun'), ('어머니', 'Noun'), ('와', 'Josa'), ('처', 'Noun'), ('에게', 'Josa'), ('폭행', 'Noun'), ('을', 'Josa'), ('가하였다', 'Verb'), ('.', 'Punctuation'), ('이', 'Noun'), ('에', 'Josa'), ('원고', 'Noun'), ('가', 'Josa'), ('화가', 'Noun'), ('나', 'Noun'), ('칼', 'Noun'), ('을', 'Josa'), ('이용', 'Noun'), ('해', 'Verb'), ('경찰관', 'Noun'), ('1', 'Number'), ('명', 'Noun'), ('을', 'Josa'), ('살해', 'Noun'), ('하였다', 'Verb'), ('(', 'Punctuation'), ('이하', 'Noun'), ('‘', 'Foreign'), ('제', 'Noun'), ('2', 'Number'), ('사유', 'Noun'), ('’', 'Punctuation'), ('라고', 'Josa'), ('한다', 'Verb'), (').', 'Punctuation'), ('3', 'Number'), (')',  ...
# <class 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c00eba75ed89> in <module>
#       2 print(type(reason))
#       3
# ----> 4 reason = reason.to_list()
#       5 print(reason[:2])
#       6 print(type(reason))
#
# AttributeError: 'list' object has no attribute 'to_list'

# %%
text = nltk.Text(tokens, name='NMSC')

print(len(text.tokens)) # 전체 토큰의 개수
print(len(set(text.tokens))) # 중복 제외한 토큰의 개수
pprint(text.vocab().most_common(10)) # 출현 빈도가 높은 상위 토큰 10개
# Out:
# 85505041
# 1811
# [("'", 20114797),
#  (',', 10241937),
#  (' ', 10045384),
#  (')', 5078488),
#  ('(', 5064750),
#  ('o', 3944268),
#  ('u', 3852255),
#  ('n', 3548228),
#  ('N', 2609040),
#  ('a', 1620435)]

# %%
plt.figure(figsize=(30,10))
text.plot(50)

# %%
X_data = law_df['이유토큰화']
y_data = law_df['승소여부']

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X_data, y_data, test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((9217,), (3073,), (9217,), (3073,))

# %%
selected_words = [f[0] for f in text.vocab().most_common(1000)]

def term_frequency(doc):
    return [doc.count(word) for word in selected_words]

train_x = [term_frequency(d) for d in X_train]
test_x = [term_frequency(d) for d in X_test]
train_y = [c for c in y_train]
test_y = [c for c in y_test]

# %%
len(train_x[0])
# Out:
# 1000

# %%
XX_train = np.asarray(train_x).astype('float32')
XX_test = np.asarray(test_x).astype('float32')

yy_train = np.asarray(train_y).astype('float32')
yy_test = np.asarray(test_y).astype('float32')

# %%
XX_train.shape, XX_test.shape, yy_train.shape, yy_test.shape
# Out:
# ((9217, 1000), (3073, 1000), (9217,), (3073,))

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(1000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
             loss=losses.binary_crossentropy,
             metrics=[metrics.binary_accuracy])

model.fit(XX_train, yy_train, epochs=10, batch_size=512)
results = model.evaluate(XX_test, yy_test)
# Out:
# Epoch 1/10
# 19/19 [==============================] - 0s 10ms/step - loss: 11.9723 - binary_accuracy: 0.5276
# Epoch 2/10
# 19/19 [==============================] - 1s 57ms/step - loss: 7.7532 - binary_accuracy: 0.5423
# Epoch 3/10
# 19/19 [==============================] - 0s 5ms/step - loss: 6.0668 - binary_accuracy: 0.5532
# Epoch 4/10
# 19/19 [==============================] - 0s 4ms/step - loss: 5.2228 - binary_accuracy: 0.5665
# Epoch 5/10
# 19/19 [==============================] - 0s 5ms/step - loss: 5.0102 - binary_accuracy: 0.5980
# Epoch 6/10
# 19/19 [==============================] - 0s 4ms/step - loss: 4.3991 - binary_accuracy: 0.5862
# Epoch 7/10
# 19/19 [==============================] - 0s 5ms/step - loss: 4.5723 - binary_accuracy: 0.5614
# Epoch 8/10
# 19/19 [==============================] - 0s 5ms/step - loss: 3.5908 - binary_accuracy: 0.5989
# Epoch 9/10
# 19/19 [==============================] - 0s 5ms/step - loss: 3.5999 - binary_accuracy: 0.5891
# Epoch 10/10
# 19/19 [==============================] - 0s 4ms/step - loss: 3.4100 - binary_accuracy: 0.5822
# 97/97 [==============================] - 0s 1ms/step - loss: 4.8089 - binary_accuracy: 0.6228

# %%
results
# Out:
# [4.808936595916748, 0.6228440999984741]

# %% [markdown]
# ------------------ 이제 아예 새로운 데이터(고객에게 받은 글) 받을 때 정확도 나타내는 것 ----------------

# %%
def tokenize(writing):
    return ['/'.join(t) for t in okt.pos(writing, norm=True, stem=True)]

# %%
def predict_pos_neg(review):

    token = tokenize(review)
    tf = term_frequency(token)
    data = np.expand_dims(np.asarray(tf).astype('float32'), axis=0)
    score = float(model.predict(data))
    if(score > 0.5):
        print("[{}]는 {:.2f}% 확률로 승소이지 않을까 추측해봅니다.^^\n".format(review, score * 100))
    else:
        print("[{}]는 {:.2f}% 확률로 패소이지 않을까 추측해봅니다.^^;\n".format(review, (1 - score) * 100))

# %%
predict_pos_neg('올해 최고의 영화! 세 번 넘게 봐도 질리지가 않네요.')
# Out:
# [올해 최고의 영화! 세 번 넘게 봐도 질리지가 않네요.]는 50.28% 확률로 승소이지 않을까 추측해봅니다.^^

# %%
predict_pos_neg('기복과 근거 없는 부정행위 의심, 폭언, 폭행을 주장한 사실이 인정된다. 그러나, 위와... 더보기 ... 따라서 피고는 원고에게 불법행위에 기한 손해배상으로 위자료 1,700만 원 및 이에 대하여 이 사건 소장 부본 송달 다음날인 2019. 11. 7.부터(원고는 불법행위의 시기인 2019. 9. 10.부터 지연손해금의 지급을 구한다고 주장하나, 원고의 청구는 부정행위 기간 전체에 대한 위자료 청구이고, 종기에 대한 주장, 입증이 없으므로, 이 사건 소장 부본 송달 다음날부터 지연손해금의 지급을 명한다) 이 판결 선고일인 2020. 10. 7.까지는 민법이 정한 연 5%, 그 다음날부터 다 갚는 날까지는 소송촉진 등에 관한 특례법이 정한 연 12%의 각 비율로 계산한 지연손해금을 지급할 의무가 있다. 3. 피고의 주장에 대한 판단 가. 주장의 요지 C와 원고의 혼인관계는 2019. 8.경부터 파탄 상태였다. 따라서, 피고와 C의 행위가 원고의 부부공동생활을 침해하거나 유지를 방해하였다고 할 수 없다. 나. 판단 을 제7호증, 갑 제11호증, 변론 전체의 취지를 종합하면, C가 2019. 10. 30. 인천가정법원 2019너16027호(2019드단115082호로 접수되었다가 재배당되었다)로 원고에 대하여 이혼 및 위자료 2,000만 원 지급을 구하는 조정신청을 한 사실, C는 신청원인으로 원고의 감정 기복과 근거 없는 부정행위 의심, 폭언, 폭행을 주장한 사실이 인정된다. 그러나, 위와 같은 사정만으로는 피고와 C의 부정행위 당시 이미 원고와 C의 부부공동생활이 실질적으로 파탄되어 실체가 더 이상 존재하지 아니하게 되고 객관적으로 회복할 수 없는 정도에 이르렀다고 보기에 부족하고 달리 이를 인정할 증거가 없다. 따라서, 피고의 주장은 이유 없다. 4. 결론 원고의 청구는 위 인정범위 내에서 이유 있으므로 이를 인용하고, 나머지 청구는 이유 없으므로 이를 기각하기로 하여 주문과 같이 판결한다')
# Out:
# [기복과 근거 없는 부정행위 의심, 폭언, 폭행을 주장한 사실이 인정된다. 그러나, 위와... 더보기 ... 따라서 피고는 원고에게 불법행위에 기한 손해배상으로 위자료 1,700만 원 및 이에 대하여 이 사건 소장 부본 송달 다음날인 2019. 11. 7.부터(원고는 불법행위의 시기인 2019. 9. 10.부터 지연손해금의 지급을 구한다고 주장하나, 원고의 청구는 부정행위 기간 전체에 대한 위자료 청구이고, 종기에 대한 주장, 입증이 없으므로, 이 사건 소장 부본 송달 다음날부터 지연손해금의 지급을 명한다) 이 판결 선고일인 2020. 10. 7.까지는 민법이 정한 연 5%, 그 다음날부터 다 갚는 날까지는 소송촉진 등에 관한 특례법이 정한 연 12%의 각 비율로 계산한 지연손해금을 지급할 의무가 있다. 3. 피고의 주장에 대한 판단 가. 주장의 요지 C와 원고의 혼인관계는 2019. 8.경부터 파탄 상태였다. 따라서, 피고와 C의 행위가 원고의 부부공동생활을 침해하거나 유지를 방해하였다고 할 수 없다. 나. 판단 을 제7호증, 갑 제11호증, 변론 전체의 취지를 종합하면, C가 2019. 10. 30. 인천가정법원 2019너16027호(2019드단115082호로 접수되었다가 재배당되었다)로 원고에 대하여 이혼 및 위자료 2,000만 원 지급을 구하는 조정신청을 한 사실, C는 신청원인으로 원고의 감정 기복과 근거 없는 부정행위 의심, 폭언, 폭행을 주장한 사실이 인정된다. 그러나, 위와 같은 사정만으로는 피고와 C의 부정행위 당시 이미 원고와 C의 부부공동생활이 실질적으로 파탄되어 실체가 더 이상 존재하지 아니하게 되고 객관적으로 회복할 수 없는 정도에 이르렀다고 보기에 부족하고 달리 이를 인정할 증거가 없다. 따라서, 피고의 주장은 이유 없다. 4. 결론 원고의 청구는 위 인정범위 내에서 이유 있으므로 이를 인용하고, 나머지 청구는 이유 없으므로 이를 기각하기로 하여 주문과 같이 판결한다]는 50.28% 확률로 승소이지 않을까 추측해봅니다.^^

# %%
predict_pos_neg('따르면, 원고는 다음과 같이 B로부터 폭행당한 경위를 설명하고 있다. “술에 취한 B가... 더보기 ... 있다고 보아야 한다. 나. 관계법령 산업재해보상보험법 제5조(정의) 이 법에서 사용하는 용어의 뜻은 다음과 같다. 1. “업무상의 재해”란 업무상의 사유에 따른 근로자의 부상질병장해 또는 사망을 말한다. 제49조(추가상병 요양급여의 신청) 업무상의 재해로 요양 중인 근로자는 다음 각 호의 어느 하나에 해당하는 경우에는 그 부상 또는 질병(이하, “추가상병”이라 한다.)에 대한 요양급여를 신청할 수 있다. 1. 그 업무상의 재해로 이미 발생한 부상이나 질병이 추가로 발견되어 요양이 필요한 경우 2. 그 업무상의 재해로 발생한 부상이나 질병이 원인이 되어 새로운 질병이 발생하여 요양이 필요한 경우 다. 인정사실 (1) 이 사건 재해의 내용에 관한 원고의 진술 2012. 2. 17.자 피고 담당공무원 작성의 문답서(갑 제5호증)에 따르면, 원고는 다음과 같이 B로부터 폭행당한 경위를 설명하고 있다. “술에 취한 B가 원고의 목부위에 휴대전화기를 던졌고, 오른손으로 턱을 가격하였다. 주변에서 사람들이 말려서 분을 삭이기 위하여 의자에 앉아 있었는데, B가 다가와 쓰레기통 뚜껑으로 원고를 때렸다. 이후 발인지 손인지 잘 모르겠으나 등을 맞았고, 의자에서 떨어져 땅바닥에 주저앉아 있을 때 발로도 밟힌 것 같다. B로부터 맞은 부위는 목, 오른쪽 턱, 등, 허리 쪽이다. 예전에 허리부위에 수술을 2번 받은 적이 있는데 이 사건 이후 병원에 가 보았더니 옛날 수술부위는 괜찮은데 그 윗부분에 이상이 생겼다고 하였다.” (2) 원고의 이 사건 재해 이전의 치료내역 원고는 2001. 6.경부터 요추부통증 및 제4-5요추-제1천추간 퇴행성 병변으로 의료기관에서 진료를 받기 시작하였고, 2009. 1.경부터 2010. 10.경까지 사이에는 7회에 걸쳐')
# Out:
# [따르면, 원고는 다음과 같이 B로부터 폭행당한 경위를 설명하고 있다. “술에 취한 B가... 더보기 ... 있다고 보아야 한다. 나. 관계법령 산업재해보상보험법 제5조(정의) 이 법에서 사용하는 용어의 뜻은 다음과 같다. 1. “업무상의 재해”란 업무상의 사유에 따른 근로자의 부상질병장해 또는 사망을 말한다. 제49조(추가상병 요양급여의 신청) 업무상의 재해로 요양 중인 근로자는 다음 각 호의 어느 하나에 해당하는 경우에는 그 부상 또는 질병(이하, “추가상병”이라 한다.)에 대한 요양급여를 신청할 수 있다. 1. 그 업무상의 재해로 이미 발생한 부상이나 질병이 추가로 발견되어 요양이 필요한 경우 2. 그 업무상의 재해로 발생한 부상이나 질병이 원인이 되어 새로운 질병이 발생하여 요양이 필요한 경우 다. 인정사실 (1) 이 사건 재해의 내용에 관한 원고의 진술 2012. 2. 17.자 피고 담당공무원 작성의 문답서(갑 제5호증)에 따르면, 원고는 다음과 같이 B로부터 폭행당한 경위를 설명하고 있다. “술에 취한 B가 원고의 목부위에 휴대전화기를 던졌고, 오른손으로 턱을 가격하였다. 주변에서 사람들이 말려서 분을 삭이기 위하여 의자에 앉아 있었는데, B가 다가와 쓰레기통 뚜껑으로 원고를 때렸다. 이후 발인지 손인지 잘 모르겠으나 등을 맞았고, 의자에서 떨어져 땅바닥에 주저앉아 있을 때 발로도 밟힌 것 같다. B로부터 맞은 부위는 목, 오른쪽 턱, 등, 허리 쪽이다. 예전에 허리부위에 수술을 2번 받은 적이 있는데 이 사건 이후 병원에 가 보았더니 옛날 수술부위는 괜찮은데 그 윗부분에 이상이 생겼다고 하였다.” (2) 원고의 이 사건 재해 이전의 치료내역 원고는 2001. 6.경부터 요추부통증 및 제4-5요추-제1천추간 퇴행성 병변으로 의료기관에서 진료를 받기 시작하였고, 2009. 1.경부터 2010. 10.경까지 사이에는 7회에 걸쳐]는 50.28% 확률로 승소이지 않을까 추측해봅니다.^^

# %% [markdown]
# # --------------------------------------------------

# %%
temp1 = law_df['이유']
reason = []
for i in temp1:
    reason.append(okt.morphs(i))

reason[:10]
# 10분 걸림 시방거~
# kkma 쓰지말자~ 느리고 성능도 별로다
# okt 최고시다
# Out:
# [['...',
#   '위해',
#   '거짓말',
#   '을',
#   '하자',
#   '어머니',
#   '와',
#   '처',
#   '에게',
#   '폭행',
#   '을',
#   '가하였다',
#   '.',
#   '이',
#   '에',
#   '원고',
#   '가',
#   '화가',
#   '나',
#   '칼',
#   '을',
#   '...',
#   '더',
#   '보기',
#   '...',
#   '이유',
#   '로',
#   '카메룬',
#   '경찰',
#   '에',
#   '의해',
#   '구속',
#   '되었다',
#   '.',
#   '원고',
#   '는',
#   '삼촌',
#   '의',
#   '부탁',
#   '으로',
#   '삼촌',
#   '집',
#   '에',
#   '있던',
#   '반정부',
#   '성향',
#   '의',
#   '책자',
#   '를',
#   '자신',
#   '의',
#   '집',
#   '에',
#   '숨겼는데',
#   ',',
#   '이를',
#   '이유',
#   '로',
#   '경찰',
#   '에',
#   '의해',
#   '체포',
#   '당',
#   '한',
#   '적',
#   '이',
#   '있고',
#   ',',
#   '2005',
#   '.',
#   '경',
#   '삼촌',
#   '의',
#   '부탁',
#   '으로',
#   'SCNC',
#   '가입',
#   '을',
#   '홍보',
#   '하는',
#   '내용',
#   '의',
#   '전단지',
#   '를',
#   '배포',
#   '하기도',
#   '하였다',
#   '.',
#   '이',
#   '와',
#   '같이',
#   '카메룬',
#   '정부',
#   '는',
#   'SCNC',
#   '회원',
#   '들',
#   '을',
#   '체포',
#   '하는',
#   '등',
#   '박해',
#   '하고',
#   '있는바',
#   ',',
#   '원고',
#   '는',
#   'SCNC',
#   '회원',
#   '이',
#   '아님에도',
#   '카메룬',
#   '정부',
#   '로부터',
#   'SCNC',
#   '회원',
#   '으로',
#   '오인',
#   '을',
#   '받고',
#   '있다',
#   '(',
#   '이하',
#   '’',
#   '제',
#   '1',
#   '사유',
#   '‘',
#   '라고',
#   '한다',
#   ').',
#   '2',
#   ')',
#   '2011',
#   '.',
#   '5',
#   '.',
#   '경',
#   '축구장',
#   '에서',
#   '선거',
#   '유세',
#   '를',
#   '하던',
#   '사람과',
#   '축구',
#   '를',
#   '하던',
#   '사람',
#   '들',
#   '사이',
#   '에',
#   '다툼',
#   '이',
#   '생겼는데',
#   ',',
#   '원고',
#   '는',
#   '그',
#   '싸움',
#   '에',
#   '관여',
#   '하지',
#   '않았었다',
#   '.',
#   '그런데',
#   '경찰',
#   '은',
#   '위',
#   '폭행',
#   '사건',
#   '의',
#   '용의자',
#   '로',
#   '원고',
#   '를',
#   '지목',
#   '한',
#   '다음',
#   '원고',
#   '를',
#   '체포',
#   '하기',
#   '위',
#   '하여',
#   '원고',
#   '의',
#   '집',
#   '에',
#   '찾아왔는데',
#   ',',
#   '원고',
#   '의',
#   '어머니',
#   '와',
#   '처가',
#   '원고',
#   '를',
#   '숨기기',
#   '위해',
#   '거짓말',
#   '을',
#   '하자',
#   '어머니',
#   '와',
#   '처',
#   '에게',
#   '폭행',
#   '을',
#   '가하였다',
#   '.',
#   '이',
#   '에',
#   '원고',
#   '가',
#   '화가',
#   '나',
#   '칼',
#   '을',
#   '이용',
#   '해',
#   '경찰관',
#   '1',
#   '명',
#   '을',
#   '살해',
#   '하였다',
#   '(',
#   '이하',
#   '‘',
#   '제',
#   '2',
#   '사유',
#   '’',
#   '라고',
#   '한다',
#   ').',
#   '3',
#   ')',
#   '따라서',
#   '원고',
#   '가',
#   '카메룬',
#   '으로',
#   '돌아갈',
#   '경우',
#   '위',
#   '와',
#   '같은',
#   '이유',
#   '로',
#   '카메룬',
#   '정부',
#   '또는',
#   '경찰',
#   '로부터',
#   '박해',
#   '를',
#   '받을',
#   '우려',
#   '가',
#   '있으므로',
#   '이',
#   '와',
#   '다른',
#   '전제',
#   '에서',
#   '이루어진',
#   '이',
#   '사건',
#   '처분',
#   '은',
#   '위법',
#   '하다',
#   '나',
#   '.',
#   '관계',
#   '법령',
#   '별',
#   '지',
#   '관계',
#   '법령',
#   '기재',
#   '와',
#   '같다',
#   '.',
#   '다',
#   '.',
#   '인정',
#   '사실',
#   '영국',
#   '이',
#   '민국',
#   '은',
#   '2009',
#   '.',
#   '6',
#   '.',
#   '1',
#   '.',
#   '자',
#   '난민',
#   '인정',
#   '처리',
#   '지침',
#   '에서',
#   '난민',
#   '인정',
#   '및',
#   '비호',
#   '부여',
#   '의',
#   '기준',
#   '에',
#   '관',
#   '하여',
#   '아래',
#   '와',
#   '같은',
#   '의견',
#   '을',
#   '제시',
#   '하였다',
#   '.',
#   '1',
#   ')',
#   'SCNC',
#   '의',
#   '몇몇',
#   '지도자',
#   '와',
#   '구성원',
#   ',',
#   '그리고',
#   '지지자',
#   '들',
#   '이',
#   '체포',
#   '되어',
#   '단기간',
#   '구금',
#   '되',
#   '기는',
#   '하였지만',
#   ',',
#   'SCNC',
#   '와',
#   'SCYL',
#   '(',
#   'Southern',
#   'Cameroons',
#   'Youth',
#   'League',
#   ',',
#   'SCNC',
#   '의',
#   '청년',
#   '단체',
#   '이다',
#   ')',
#   '의',
#   '평범한',
#   '구성원',
#   '들',
#   '에',
#   '대한',
#   '처우',
#   '가',
#   '일반',
#   '적',
#   '으로',
#   '박해',
#   '에',
#   '이를',
#   '정도',
#   '라는',
#   '증거',
#   '는',
#   '없다',
#   '.',
#   '단순히',
#   '구성원',
#   '이라',
#   '거나',
#   '관련',
#   '이',
#   '있다거나',
#   '그렇게',
#   '인지',
#   '되었다는',
#   '점',
#   '만으로',
#   '...'],
#  ['...,',
#   '이하',
#   '‘',
#   'PML',
#   '-',
#   'N',
#   "'",
#   '이라고',
#   '한다',
#   ')',
#   '정당',
#   '원',
#   '들',
#   '로부터',
#   '폭행',
#   '을',
#   '당하였다',
#   '.',
#   '따라서',
#   '원고',
#   '는',
#   '파키스탄',
#   '으로',
#   '...',
#   '더',
#   '보기',
#   '...',
#   '하였으나',
#   ',',
#   '위',
#   '이의신청',
#   '은',
#   '2014',
#   '.',
#   '9',
#   '.',
#   '30',
#   '.',
#   '기각',
#   '되었다',
#   '.',
#   '3',
#   ')',
#   '한편',
#   ',',
#   '원고',
#   '는',
#   '위',
#   '난민',
#   '인정',
#   '신청',
#   '이후',
#   '인',
#   '2014',
#   '.',
#   '10',
#   '.',
#   '7',
#   '.',
#   '부터',
#   '2014',
#   '.',
#   '12',
#   '.',
#   '26',
#   '.',
#   '까지',
#   '다시',
#   '파키스탄',
#   '을',
#   '방문',
#   '하였다',
#   '.',
#   '[',
#   '인정',
#   '근거',
#   ']',
#   '다툼',
#   '없는',
#   '사실',
#   ',',
#   '갑',
#   '제',
#   '1',
#   ',',
#   '2',
#   '호증',
#   ',',
#   '을',
#   '제',
#   '1',
#   ',',
#   '2',
#   '호증',
#   '(',
#   '가지',
#   '번호',
#   '있는',
#   '것',
#   '은',
#   '가지',
#   '번호',
#   '포함',
#   ')',
#   '의',
#   '각',
#   '기재',
#   '및',
#   '변론',
#   '전체',
#   '의',
#   '취지',
#   '2',
#   '.',
#   '이',
#   '사건',
#   '처분',
#   '의',
#   '적법',
#   '여부',
#   '가',
#   '.',
#   '원고',
#   '의',
#   '주장',
#   '원고',
#   '의',
#   '형',
#   'B',
#   '는',
#   '파키스탄',
#   '인민',
#   '당',
#   '(',
#   'Pakistan',
#   'Peoples',
#   'Party',
#   ',',
#   '이하',
#   '‘',
#   'PPP',
#   '’',
#   '라고',
#   '한다',
#   ')',
#   '에',
#   '가입',
#   '하여',
#   '2005',
#   '.',
#   '경',
#   '부터',
#   '2008',
#   '.',
#   '경',
#   '까지',
#   'General',
#   'Counseler',
#   '직책',
#   '으로',
#   '활동',
#   '하였고',
#   ',',
#   '2',
#   '차례',
#   '에',
#   '걸쳐',
#   '위',
#   '정당',
#   '소속',
#   '으로',
#   '선거',
#   '에',
#   '출마',
#   '하여',
#   '당선',
#   '되었는데',
#   ',',
#   '원고',
#   '는',
#   'PPP',
#   '당원',
#   '은',
#   '아니었지만',
#   '단순',
#   '지지자',
#   '로서',
#   '원고',
#   '의',
#   '형',
#   '을',
#   '위',
#   '하여',
#   '선거운동',
#   '을',
#   '하였다',
#   '.',
#   '원고',
#   '와',
#   '원고',
#   '의',
#   '형',
#   '은',
#   '2012',
#   '.',
#   '6',
#   '.',
#   '28',
#   '.',
#   '경',
#   'PPP',
#   '정당',
#   '에',
#   '적대',
#   '적',
#   '인',
#   '파키스탄',
#   '무슬림',
#   '리그',
#   '-',
#   'N',
#   '(',
#   'Pakistan',
#   'Muslim',
#   'League',
#   '-',
#   'Nawaz',
#   ',',
#   '이하',
#   '‘',
#   'PML',
#   '-',
#   'N',
#   "'",
#   '이라고',
#   '한다',
#   ')',
#   '정당',
#   '원',
#   '들',
#   '로부터',
#   '폭행',
#   '을',
#   '당하였다',
#   '.',
#   '따라서',
#   '원고',
#   '는',
#   '파키스탄',
#   '으로',
#   '귀국',
#   '할',
#   '경우',
#   '정치',
#   '적',
#   '의견',
#   '을',
#   '원인',
#   '으로',
#   'PML',
#   '-',
#   'N',
#   '으로부터',
#   '박해',
#   '를',
#   '받을',
#   '우려',
#   '가',
#   '있으므로',
#   '이',
#   '와',
#   '다른',
#   '전제',
#   '에서',
#   '이루어진',
#   '이',
#   '사건',
#   '처분',
#   '은',
#   '위법',
#   '하다',
#   '.',
#   '나',
#   '.',
#   '관계',
#   '법령',
#   '별',
#   '지',
#   '관계',
#   '법령',
#   '기재',
#   '와',
#   '같다',
#   '.',
#   '다',
#   '.',
#   '판단',
#   '1',
#   ')',
#   '난민',
#   '의',
#   '요건',
#   '및',
#   '증명책임',
#   '구',
#   '출입국관리법',
#   '(',
#   '2012',
#   '.',
#   '2',
#   '.',
#   '10',
#   '.',
#   '법률',
#   '제',
#   '11298',
#   '호로',
#   '개정',
#   '되기',
#   '전의',
#   '것',
#   ')',
#   '제',
#   '2조',
#   '제',
#   '3',
#   '호',
#   ',',
#   '제',
#   '76조',
#   '의',
#   '2',
#   '제',
#   '1',
#   '항',
#   ',',
#   '난민',
#   '협약',
#   '제',
#   '1조',
#   ',',
#   '난민',
#   '의정서',
#   '제',
#   '1조',
#   '의',
#   '규정',
#   '을',
#   '종합',
#   '하여',
#   '보면',
#   ',',
#   '법무부',
#   '장관',
#   '은',
#   '인종',
#   ',',
#   '종교',
#   ',',
#   '국적',
#   ',',
#   '특정',
#   '사회',
#   '집단',
#   '의',
#   '구성원',
#   '신분',
#   '또는',
#   '정치',
#   '적',
#   '의견',
#   '을',
#   '이유',
#   '로',
#   '박해',
#   '를',
#   '받을',
#   '충분한',
#   '근거',
#   '있는',
#   '공포',
#   '로',
#   '인해',
#   '국적',
#   '국',
#   '의',
#   '보호',
#   '를',
#   '받을',
#   '수',
#   '없거나',
#   '국적',
#   '국',
#   '의',
#   '보호',
#   '를',
#   '원하지',
#   '않는',
#   '대한민국',
#   '안',
#   '에',
#   '있는',
#   '외국인',
#   '에',
#   '대하',
#   '여',
#   '그',
#   '신청',
#   '이',
#   '있는',
#   '경우',
#   '난민',
#   '협약',
#   '이',
#   '정',
#   '하는',
#   '난민',
#   '으로',
#   '인정',
#   '하여야',
#   '한다',
#   '.',
#   '이',
#   '때',
#   '난민',
#   '인정',
#   '의',
#   '요건',
#   '이',
#   '되는',
#   '‘',
#   '박해',
#   '’',
#   '라',
#   '함',
#   '은',
#   '...'],
#  ['...',
#   '치료',
#   '를',
#   '받게',
#   '된',
#   '것',
#   '으로',
#   '이를',
#   '상해',
#   '또는',
#   '폭행',
#   '으로',
#   '보기',
#   '는',
#   '어렵다',
#   '.',
#   '다',
#   ')',
#   '제',
#   '3',
#   '징계',
#   '사유',
#   '에',
#   '...',
#   '더',
#   '보기',
#   '...',
#   '2013',
#   '.',
#   '11',
#   '.',
#   '18',
#   '.',
#   '원고',
#   '의',
#   '위',
#   '청구',
#   '를',
#   '기각',
#   '하였다',
#   '.',
#   '[',
#   '인정',
#   '근거',
#   ']',
#   '다툼',
#   '없는',
#   '사실',
#   ',',
#   '갑',
#   '제',
#   '1',
#   ',',
#   '2',
#   '호증',
#   '(',
#   '가지',
#   '번호',
#   '포함',
#   ')',
#   '의',
#   '각',
#   '기재',
#   ',',
#   '변론',
#   '전체',
#   '의',
#   '취지',
#   '2',
#   '.',
#   '이',
#   '사건',
#   '처분',
#   '의',
#   '적법',
#   '여부',
#   '가',
#   '.',
#   '원고',
#   '의',
#   '주장',
#   '1',
#   ')',
#   '징계',
#   '사유',
#   '부존재',
#   '가',
#   ')',
#   '제',
#   '1',
#   '징계',
#   '사유',
#   '에',
#   '대하',
#   '여',
#   '원고',
#   '는',
#   'H',
#   ',',
#   'F',
#   ',',
#   'G',
#   ',',
#   'E',
#   '과',
#   '상호',
#   '호의',
#   '적',
#   '인',
#   '관계',
#   '를',
#   '맺고',
#   '있었고',
#   ',',
#   '단지',
#   '의견',
#   '차이',
#   '로',
#   '인한',
#   '다툼',
#   '이',
#   '있었을',
#   '뿐',
#   '따돌림',
#   '행위',
#   '는',
#   '없었다',
#   '.',
#   '나',
#   ')',
#   '제',
#   '2',
#   '징계',
#   '사유',
#   '에',
#   '대하',
#   '여',
#   '원고',
#   '는',
#   ',',
#   '①',
#   '평소',
#   '가깝게',
#   '지내던',
#   'I',
#   '에게',
#   '5,000원',
#   '가량',
#   '의',
#   '돈',
#   '을',
#   '빌린',
#   '적은',
#   '있어도',
#   'I',
#   '에게',
#   '금품',
#   '을',
#   '요구',
#   '하',
#   '거나',
#   '갈취',
#   '한',
#   '사실',
#   '은',
#   '없고',
#   ',',
#   '②',
#   'J',
#   '도',
#   '원고',
#   '와',
#   '친한',
#   '사이',
#   '로',
#   '서로',
#   '간의',
#   '장난',
#   '으로',
#   '이',
#   '사건',
#   '지',
#   '급서',
#   '를',
#   '작성',
#   '하게',
#   '한',
#   '것',
#   '이며',
#   ',',
#   '③',
#   'K',
#   ',',
#   'L',
#   '이',
#   '근무시간',
#   '에',
#   '인터넷',
#   '을',
#   '하고',
#   '고스톱',
#   '을',
#   '치는',
#   '행위',
#   '를',
#   '하여',
#   '구',
#   '두',
#   '경고',
#   '와',
#   '더불어',
#   '친',
#   '근',
#   '감',
#   '의',
#   '표시',
#   '로',
#   'K',
#   ',',
#   'L',
#   '의',
#   '손가락',
#   '을',
#   '약간',
#   '세게',
#   '쥐는',
#   '바람',
#   '에',
#   '두',
#   '사람',
#   '이',
#   '치료',
#   '를',
#   '받게',
#   '된',
#   '것',
#   '으로',
#   '이를',
#   '상해',
#   '또는',
#   '폭행',
#   '으로',
#   '보기',
#   '는',
#   '어렵다',
#   '.',
#   '다',
#   ')',
#   '제',
#   '3',
#   '징계',
#   '사유',
#   '에',
#   '대하',
#   '여',
#   '원고',
#   '는',
#   '스포츠',
#   '마사지',
#   '자격',
#   '을',
#   '취득',
#   '하여',
#   '보유',
#   '하고',
#   '있고',
#   ',',
#   '이',
#   '사건',
#   '당시',
#   '사무실',
#   '직원',
#   '들',
#   '을',
#   '마사지',
#   '해주는',
#   '과정',
#   '에서',
#   'M',
#   '이',
#   '피곤한',
#   '안색',
#   '을',
#   '보여',
#   '자연',
#   '스럽게',
#   '어깨',
#   '를',
#   '2~3회',
#   '주물러',
#   '준',
#   '것일',
#   '뿐',
#   'M',
#   '에게',
#   '성적',
#   '수치심',
#   '을',
#   '주었다고',
#   '볼',
#   '수',
#   '없다',
#   '.',
#   '라',
#   ')',
#   '제',
#   '4',
#   '징계',
#   '사유',
#   '에',
#   '대하',
#   '여',
#   '원고',
#   '가',
#   '담당',
#   '관',
#   'N',
#   ',',
#   '팀',
#   '장',
#   'O',
#   '에게',
#   '몇',
#   '차례',
#   '직무',
#   '와',
#   '관련',
#   '된',
#   '건의',
#   '를',
#   '한',
#   '사실',
#   '은',
#   '있으나',
#   '강하게',
#   '항의',
#   '한',
#   '사실',
#   '은',
#   '없고',
#   ',',
#   '좌석',
#   '배치',
#   '및',
#   '근무',
#   '편성',
#   '에',
#   '관',
#   '하여',
#   '언쟁',
#   '을',
#   '한',
#   '것',
#   '은',
#   'H',
#   '이며',
#   '원고',
#   '는',
#   '그',
#   '과정',
#   '에서',
#   '동조',
#   '한',
#   '것',
#   '에',
#   '불과하다',
#   '.',
#   '2',
#   ')',
#   '재량',
#   '권',
#   '의',
#   '일',
#   '탈',
#   'ㆍ',
#   '남용',
#   '이',
#   '사건',
#   '처분',
#   '의',
#   '각',
#   '징계',
#   '사유',
#   '는',
#   '법원',
#   '공무원',
#   '징계',
#   '양정',
#   '등',
#   '에',
#   '관',
#   '한',
#   '예규',
#   '(',
#   '이하',
#   '‘',
#   '징계',
#   '양정',
#   '예규',
#   '’',
#   '라고',
#   '한다',
#   ')',
#   '[',
#   '별표',
#   '1',
#   ']',
#   '에서',
#   '정',
#   '한',
#   '‘',
#   '비위',
#   '의',
#   '도',
#   '가',
#   '중하',
#   '고',
#   '고의',
#   '가',
#   '있는',
#   '경우',
#   '’',
#   '라고',
#   '볼',
#   '수',
#   '없는',
#   '점',
#   ',',
#   '원고',
#   '는',
#   '법원',
#   '경비',
#   '관리',
#   '대원',
#   '으로',
#   '근무',
#   '하면서',
#   '표창장',
#   '과',
#   '...'],
#  ['...',
#   '위',
#   '와',
#   '같이',
#   '원고',
#   'A',
#   '를',
#   '폭행',
#   '하였다는',
#   '범죄',
#   '사실',
#   '로',
#   '...',
#   '기소',
#   '되어',
#   '성폭력',
#   '...',
#   '더',
#   '보기',
#   '...',
#   '보자',
#   '”',
#   '라고',
#   '말',
#   '하며',
#   '갑자기',
#   '피해자',
#   '의',
#   '볼',
#   '과',
#   '입술',
#   '에',
#   '입',
#   '을',
#   '맞췄다',
#   '.',
#   '계속',
#   '하여',
#   '피고',
#   '는',
#   '원고',
#   'C',
#   '에게',
#   '“',
#   '아',
#   ',',
#   '진짜',
#   '너',
#   '는',
#   '너무',
#   '튼튼해서',
#   '좋아',
#   '”',
#   '라고',
#   '말',
#   '하면서',
#   '원고',
#   'C',
#   '의',
#   '가슴',
#   '을',
#   '만',
#   '지고',
#   ',',
#   '반항',
#   '하는',
#   '원고',
#   'C',
#   '의',
#   '손목',
#   '을',
#   '잡고',
#   '원고',
#   'C',
#   '에게',
#   '입',
#   '을',
#   '맞추었다',
#   '.',
#   '3',
#   ')',
#   '피고',
#   '는',
#   '2012년',
#   '1월',
#   '중순',
#   '일자',
#   '불상',
#   '14:00',
#   '경',
#   '위',
#   '와',
#   '같은',
#   '장소',
#   '에서',
#   ',',
#   '원고',
#   'C',
#   '에게',
#   '“',
#   'C',
#   '야',
#   ',',
#   '진짜',
#   '너',
#   '는',
#   '보면',
#   '볼수록',
#   '너무',
#   '탐',
#   '난다',
#   '”',
#   '라고',
#   '말',
#   '하며',
#   '갑자기',
#   '원고',
#   'C',
#   '의',
#   '뺨',
#   '에',
#   '입',
#   '을',
#   '맞추었다',
#   '.',
#   '마',
#   '.',
#   '피고',
#   '에',
#   '대한',
#   '형사',
#   '판결',
#   '피고',
#   '는',
#   '위',
#   '와',
#   '같이',
#   '원고',
#   'A',
#   '를',
#   '폭행',
#   '하였다는',
#   '범죄',
#   '사실',
#   '로',
#   '약식',
#   '기소',
#   '되어',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '11',
#   '.',
#   '대구',
#   '지방법원',
#   '2012',
#   '고약',
#   '6729',
#   '호로',
#   '피고',
#   '에게',
#   '벌금',
#   '150만',
#   '원',
#   '의',
#   '약식',
#   '명령',
#   '이',
#   '내려졌다',
#   '(',
#   '피고',
#   '는',
#   '위',
#   '약식',
#   '명령',
#   '에',
#   '대해',
#   '대구',
#   '지방법원',
#   '2012',
#   '고정',
#   '1741',
#   '호로',
#   '정식',
#   '재판',
#   '청구',
#   '를',
#   '하여',
#   '벌금',
#   '100만',
#   '원',
#   '으로',
#   '감액',
#   '되어',
#   '확정',
#   '되었다',
#   ').',
#   '또한',
#   ',',
#   '피고',
#   '는',
#   '위',
#   '와',
#   '같이',
#   '원고',
#   'B',
#   ',',
#   'C',
#   '를',
#   '강제추행',
#   '하였다는',
#   '범죄',
#   '사실',
#   '로',
#   '기소',
#   '되어',
#   '성폭력',
#   '범죄',
#   '의',
#   '처벌',
#   '등',
#   '에',
#   '관',
#   '한',
#   '특례법',
#   '위반',
#   '(',
#   '주거침입',
#   '강간',
#   '등',
#   ')',
#   '등',
#   '죄',
#   '로',
#   '2014',
#   '.',
#   '3',
#   '.',
#   '19',
#   '.',
#   '대구',
#   '고등법원',
#   '2013',
#   '노',
#   '448',
#   '호로',
#   '징역',
#   '2년',
#   '6월',
#   '의',
#   '집행유예',
#   '3년',
#   ',',
#   '성폭력',
#   '치료',
#   '강의',
#   '수강',
#   '80시간',
#   '의',
#   '판결',
#   '을',
#   '선고',
#   '받고',
#   '상고',
#   '하였으나',
#   '2014',
#   '.',
#   '12',
#   '.',
#   '11',
#   '.',
#   '대법원',
#   '2014',
#   '도',
#   '4119',
#   '호로',
#   '상고',
#   '가',
#   '기각',
#   '되어',
#   '위',
#   '판결',
#   '이',
#   '그대로',
#   '확정',
#   '되었다',
#   '.',
#   '【',
#   '인정',
#   '근거',
#   '】',
#   '다툼',
#   '없는',
#   '사실',
#   ',',
#   '갑',
#   '제',
#   '1~3',
#   '호증',
#   ',',
#   '갑',
#   '제',
#   '6',
#   '호증',
#   '의',
#   '1',
#   ',',
#   '2',
#   ',',
#   '갑',
#   '제',
#   '7',
#   '호증',
#   '의',
#   '1~11',
#   ',',
#   '갑',
#   '제',
#   '7',
#   '호증',
#   '의',
#   '1~43',
#   ',',
#   '갑',
#   '제',
#   '8',
#   '호증',
#   '의',
#   '1',
#   ',',
#   '2',
#   '의',
#   '각',
#   '기재',
#   ',',
#   '변론',
#   '전체',
#   '의',
#   '취지',
#   '2',
#   '.',
#   '손해배상',
#   '책임',
#   '의',
#   '발생',
#   '가',
#   '.',
#   '책임',
#   '의',
#   '발생',
#   '위',
#   '인정',
#   '사실',
#   '에',
#   '의하면',
#   ',',
#   '피고',
#   '의',
#   '위',
#   '각',
#   '행위',
#   '는',
#   '각',
#   '원고',
#   '들',
#   '에',
#   '대한',
#   '불법행위',
#   '이므로',
#   '피고',
#   '는',
#   '위',
#   '각',
#   '불법행위',
#   '로',
#   '인하여',
#   '원고',
#   '들',
#   '이',
#   '입은',
#   '손해',
#   '를',
#   '배상',
#   '할',
#   '의무',
#   '가',
#   '있고',
#   ',',
#   '피고',
#   '의',
#   '원고',
#   'B',
#   ',',
#   'C',
#   '에',
#   '대한',
#   '강제추행',
#   '행위',
#   '로',
#   '인하여',
#   '위',
#   '원고',
#   '들',
#   '의',
#   '어머니',
#   '인',
#   '원고',
#   'A',
#   '가',
#   '상당한',
#   '정도',
#   '의',
#   '정신',
#   '적',
#   '고통',
#   '을',
#   '받았을',
#   '것임',
#   '은',
#   '경험칙',
#   '상',
#   '...'],
#  ['...',
#   '길',
#   '에',
#   '성명',
#   '불상',
#   '의',
#   '4',
#   '명의',
#   '남성',
#   '들',
#   '로부터',
#   '폭행',
#   '및',
#   '협박',
#   '을',
#   '당하였다',
#   '.',
#   '위',
#   '남성',
#   '들',
#   '을',
#   '사복',
#   '을',
#   '...',
#   '더',
#   '보기',
#   '...',
#   '원고',
#   '를',
#   '조사',
#   '하던',
#   '중',
#   '군',
#   '당국',
#   '에',
#   '원고',
#   '의',
#   '신병',
#   '을',
#   '인계',
#   '하였다',
#   '.',
#   '이',
#   '에',
#   '원고',
#   '는',
#   '룽산',
#   '(',
#   'Rung',
#   '山',
#   ')',
#   '에',
#   '위치',
#   '한',
#   '군부',
#   '대',
#   '에서',
#   '조사',
#   '를',
#   '받았는데',
#   ',',
#   '당시',
#   '미얀마',
#   '군',
#   '당국',
#   '은',
#   '원고',
#   '의',
#   '활동',
#   '이',
#   '불교',
#   '신념',
#   '에',
#   '어긋나고',
#   '미얀마',
#   '군부',
#   '와',
#   '불교도',
#   '들',
#   '이',
#   '세운',
#   '“',
#   '국가',
#   '인종',
#   '청년',
#   '개발',
#   '학교',
#   '”',
#   '(',
#   'National',
#   'Races',
#   'Youth',
#   'Development',
#   'School',
#   ')',
#   '의',
#   '활동',
#   '에',
#   '걸림',
#   '돌이',
#   '된다고',
#   '경고',
#   '하였으며',
#   ',',
#   '원고',
#   '가',
#   '미얀마',
#   '어디',
#   '로',
#   '가도',
#   '추적',
#   '할',
#   '수',
#   '있다고',
#   '협박',
#   '하였다',
#   '.',
#   '원고',
#   '는',
#   '2011',
#   '.',
#   '8',
#   '.',
#   '8',
#   '.',
#   '록렁',
#   '(',
#   'Loklung',
#   ')',
#   '이라는',
#   '이름',
#   '의',
#   '마을',
#   '에',
#   '있는',
#   '목사',
#   '친구',
#   '를',
#   '만나기',
#   '위해',
#   '위',
#   '마을',
#   '을',
#   '방문',
#   '하였다',
#   '.',
#   '위',
#   '마을',
#   '은',
#   '기독교인',
#   '들',
#   '로',
#   '이루어진',
#   '마을',
#   '로서',
#   '설교',
#   '등',
#   '의',
#   '종교',
#   '활동',
#   '을',
#   '수행',
#   '하는',
#   '데',
#   '에',
#   '당국',
#   '에',
#   '허가',
#   '가',
#   '필요하지',
#   '않았다',
#   '.',
#   '원고',
#   '는',
#   '위',
#   '마을',
#   '을',
#   '3일',
#   '간',
#   '방문',
#   '하는',
#   '김',
#   '에',
#   '위',
#   '목사',
#   '친구',
#   '의',
#   '집',
#   '에서',
#   '설교',
#   '활동',
#   '을',
#   '하였다',
#   '.',
#   '원고',
#   '는',
#   '록렁',
#   '마을',
#   '방문',
#   '일정',
#   '을',
#   '마치',
#   '고',
#   '돌아오는',
#   '길',
#   '에',
#   '성명',
#   '불상',
#   '의',
#   '4',
#   '명의',
#   '남성',
#   '들',
#   '로부터',
#   '폭행',
#   '및',
#   '협박',
#   '을',
#   '당하였다',
#   '.',
#   '위',
#   '남성',
#   '들',
#   '을',
#   '사복',
#   '을',
#   '입었고',
#   '버마어',
#   '를',
#   '사용',
#   '하였으며',
#   ',',
#   '원고',
#   '에게',
#   '폭행',
#   '및',
#   '협박',
#   '을',
#   '가한',
#   '후',
#   '원고',
#   '를',
#   '나무',
#   '에',
#   '묶은',
#   '뒤',
#   '침',
#   '을',
#   '뱉고',
#   '떠났다',
#   '.',
#   '원고',
#   '는',
#   '위',
#   '와',
#   '같은',
#   '일',
#   '을',
#   '당한',
#   '후',
#   '신변',
#   '의',
#   '위협',
#   '을',
#   '느껴',
#   '2011',
#   '.',
#   '11',
#   '.',
#   '경',
#   '양곤',
#   '의',
#   '북',
#   '다',
#   '곤',
#   '지역',
#   '에서',
#   '목회',
#   '활동',
#   '을',
#   '하였다',
#   '.',
#   '양곤',
#   '에는',
#   '불교도',
#   '들',
#   '이',
#   '다수',
#   '를',
#   '이루고',
#   '있으나',
#   '북',
#   '다',
#   '곤',
#   '지역',
#   '은',
#   '기독교인',
#   '들',
#   '이',
#   '많이',
#   '거주',
#   '하고',
#   '있어',
#   '원고',
#   '는',
#   '북',
#   '다',
#   '곤',
#   '지역',
#   '이',
#   '안전하다고',
#   '느꼈다',
#   '.',
#   '양곤',
#   '에서',
#   '기독교',
#   '행사',
#   '를',
#   '열기',
#   '위',
#   '해서는',
#   '정부',
#   '의',
#   '허가',
#   '를',
#   '받아야',
#   '하는데',
#   ',',
#   '위',
#   '허가',
#   '가',
#   '쉽게',
#   '이루어지지',
#   '않고',
#   ',',
#   '허가',
#   '없이',
#   '기독교',
#   '행사',
#   '가',
#   '개최',
#   '될',
#   '경우',
#   '미얀마',
#   '정부',
#   '가',
#   '이를',
#   '단속',
#   '하',
#   '는바',
#   ',',
#   '원고',
#   '는',
#   '위',
#   '와',
#   '같은',
#   '사실',
#   '을',
#   '알',
#   '고',
#   '북',
#   '다',
#   '곤',
#   '지역',
#   '으로',
#   '갔다',
#   '.',
#   '원고',
#   '는',
#   '2011',
#   '.',
#   '11',
#   '.',
#   '13',
#   '.',
#   '원고',
#   '가',
#   '다니던',
#   '교회',
#   '의',
#   '소',
#   '그룹',
#   '모임',
#   '을',
#   '마치',
#   '고',
#   '집',
#   '으로',
#   '돌아가던',
#   '중',
#   '성명',
#   '불상',
#   '의',
#   '4~5',
#   '명의',
#   '남자',
#   '들',
#   '로부터',
#   '공격',
#   '을',
#   '당할',
#   '뻔하였다',
#   '....'],
#  ['...',
#   '2013',
#   '.',
#   '3',
#   '.',
#   '10',
#   '.',
#   '경',
#   '손',
#   '과',
#   '막대기',
#   '로',
#   '원고',
#   '를',
#   '폭행',
#   '하게',
#   '하였다',
#   '.',
#   '이처럼',
#   '원고',
#   '가',
#   '파키스탄',
#   '으로',
#   '...',
#   '더',
#   '보기',
#   '...',
#   '‘',
#   '이',
#   '사건',
#   '처분',
#   '’',
#   '이라',
#   '한다',
#   ')',
#   '을',
#   '하였다',
#   '.',
#   '원고',
#   '는',
#   '2014',
#   '.',
#   '2',
#   '.',
#   '25',
#   '.',
#   '법무부',
#   '장관',
#   '에게',
#   '이의신청',
#   '을',
#   '하였으나',
#   '2014',
#   '.',
#   '9',
#   '.',
#   '30',
#   '.',
#   '기각',
#   '되었다',
#   '.',
#   '【',
#   '인정',
#   '근거',
#   '】',
#   '다툼',
#   '없는',
#   '사실',
#   ',',
#   '갑',
#   '제',
#   '1',
#   ',',
#   '2',
#   '호증',
#   ',',
#   '을',
#   '제',
#   '1',
#   ',',
#   '2',
#   '호증',
#   '의',
#   '각',
#   '기재',
#   ',',
#   '변론',
#   '전체',
#   '의',
#   '취지',
#   '이',
#   '사건',
#   '처분',
#   '의',
#   '적법',
#   '여부',
#   '원고',
#   '의',
#   '주장',
#   '원고',
#   '는',
#   '2002',
#   '.',
#   '경',
#   '부터',
#   '가족',
#   '들',
#   '과',
#   '함께',
#   '펀잡',
#   '(',
#   'Punjab',
#   ')',
#   '주',
#   '시알',
#   '콧',
#   '(',
#   'Sialkot',
#   ')',
#   '지역',
#   '의',
#   '주요',
#   '정당',
#   '이었던',
#   '‘',
#   '파키스탄',
#   '국민당',
#   '’(',
#   'Pakistan',
#   'People',
#   "'",
#   's',
#   'Party',
#   ',',
#   '이하',
#   "'",
#   'PPP',
#   "'",
#   '라',
#   '한다',
#   ')',
#   '의',
#   '당원',
#   '으로',
#   '활동',
#   '하였는데',
#   ',',
#   '위',
#   '지역',
#   '에서',
#   '그',
#   '반대파',
#   '인',
#   '‘',
#   '파키스탄',
#   '이슬람',
#   '동맹',
#   '-',
#   'N',
#   '’(',
#   'Pakistan',
#   'Muslim',
#   'League',
#   'Nawaz',
#   'Sharif',
#   ',',
#   '이하',
#   '‘',
#   'PML',
#   '-',
#   'N',
#   "'",
#   '이라',
#   '한다',
#   ')',
#   '의',
#   '세력',
#   '이',
#   '점차',
#   '늘어나',
#   '원고',
#   '가',
#   '마지막',
#   '으로',
#   '파키스탄',
#   '을',
#   '방문',
#   '한',
#   '2012',
#   '.',
#   '2',
#   '.',
#   '경',
#   '에는',
#   'PML',
#   '-',
#   'N',
#   '당원',
#   '들',
#   '이',
#   '원고',
#   '에게',
#   '가입',
#   '을',
#   '요구',
#   '하였고',
#   ',',
#   '원고',
#   '가',
#   '거절',
#   '하자',
#   'PML',
#   '-',
#   'N',
#   '주',
#   '의회',
#   '의원',
#   '의',
#   '아들',
#   '이',
#   '6',
#   '명의',
#   'PML',
#   '-',
#   'N',
#   '당원',
#   '들',
#   '을',
#   '사주',
#   '하여',
#   '2013',
#   '.',
#   '3',
#   '.',
#   '10',
#   '.',
#   '경',
#   '손',
#   '과',
#   '막대기',
#   '로',
#   '원고',
#   '를',
#   '폭행',
#   '하게',
#   '하였다',
#   '.',
#   '이처럼',
#   '원고',
#   '가',
#   '파키스탄',
#   '으로',
#   '돌아갈',
#   '경우',
#   '정치',
#   '적',
#   '의견',
#   '을',
#   '이유',
#   '로',
#   '박해',
#   '를',
#   '받을',
#   '위험',
#   '이',
#   '있는데도',
#   '피고',
#   '는',
#   '원고',
#   '를',
#   '난민',
#   '으로',
#   '인정',
#   '하지',
#   '않았으니',
#   '이',
#   '사건',
#   '처분',
#   '은',
#   '위법',
#   '하다',
#   '.',
#   '관계',
#   '법령',
#   '난민',
#   '법',
#   '제',
#   '2조',
#   '(',
#   '정의',
#   ')',
#   '이',
#   '법',
#   '에서',
#   '사용',
#   '하는',
#   '용어',
#   '의',
#   '뜻',
#   '은',
#   '다음',
#   '과',
#   '같다',
#   '.',
#   '1',
#   '.',
#   '"',
#   '난민',
#   '"',
#   '이란',
#   '인종',
#   ',',
#   '종교',
#   ',',
#   '국적',
#   ',',
#   '특정',
#   '사회',
#   '집단',
#   '의',
#   '구성원',
#   '인',
#   '신분',
#   '또는',
#   '정치',
#   '적',
#   '견해',
#   '를',
#   '이유',
#   '로',
#   '박해',
#   '를',
#   '받을',
#   '수',
#   '있다고',
#   '인정',
#   '할',
#   '충분한',
#   '근거',
#   '가',
#   '있는',
#   '공포',
#   '로',
#   '인하여',
#   '국적',
#   '국',
#   '의',
#   '보호',
#   '를',
#   '받을',
#   '수',
#   '없거나',
#   '보호',
#   '받기를',
#   '원하지',
#   '아니하는',
#   '외국인',
#   '또는',
#   '그러한',
#   '공포',
#   '로',
#   '인하여',
#   '대한민국',
#   '에',
#   '입국',
#   '하기',
#   '전',
#   '에',
#   '거주',
#   '한',
#   '국가',
#   '(',
#   '이하',
#   '"',
#   '상주',
#   '국',
#   '"',
#   '이라',
#   '한다',
#   ')',
#   '로',
#   '돌아갈',
#   '수',
#   '없거나',
#   '돌아가기를',
#   '원하지',
#   '아니하는',
#   '무국적자',
#   '인',
#   '외국인',
#   '을',
#   '말',
#   '한다',
#   '.',
#   '판',
#   '단',
#   '살피건대',
#   ',',
#   '을',
#   '제',
#   '1',
#   '내지',
#   '5',
#   '호증',
#   '의',
#   '각',
#   '기재',
#   '에',
#   '변론',
#   '전체',
#   '의',
#   '취지',
#   '를',
#   '종합',
#   '하여',
#   '알',
#   '수',
#   '있는',
#   '다음',
#   '과',
#   '같은',
#   '사정',
#   '에',
#   '비추어',
#   '...'],
#  ['...,',
#   '난민',
#   '면접',
#   '당시',
#   '에는',
#   '납치',
#   '범',
#   '들',
#   '로부터',
#   '폭행',
#   '을',
#   '당하지',
#   '않았다고',
#   '진술',
#   '을',
#   '번복',
#   '하였다',
#   '....',
#   '더',
#   '보기',
#   '...',
#   '할',
#   '당시',
#   '작성',
#   '한',
#   '난민',
#   '인정',
#   '신청서',
#   '에는',
#   ',',
#   '자신',
#   '이',
#   '2012',
#   '.',
#   '3',
#   '.',
#   '경',
#   '파키스탄',
#   '을',
#   '방문',
#   '하였을',
#   '때',
#   '수니파',
#   '신도',
#   '들',
#   '이',
#   '대한민국',
#   '에서',
#   '취업',
#   '활동',
#   '을',
#   '한',
#   '원고',
#   '가',
#   '재정',
#   '적',
#   '으로',
#   '넉넉할',
#   '것',
#   '이라고',
#   '여겨',
#   '원고',
#   '에게',
#   '큰',
#   '돈',
#   '을',
#   '기부',
#   '할',
#   '것',
#   '을',
#   '요구',
#   '하였고',
#   ',',
#   '원고',
#   '가',
#   '이를',
#   '거부',
#   '하자',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '10',
#   '.',
#   '경',
#   '원고',
#   '를',
#   '납치',
#   '한',
#   '뒤',
#   '몸값',
#   '으로',
#   '큰',
#   '돈',
#   '을',
#   '요구',
#   '하였다고',
#   '기재',
#   '되어',
#   '있다',
#   '.',
#   '그러나',
#   '원고',
#   '는',
#   '2014',
#   '.',
#   '2',
#   '.',
#   '3',
#   '.',
#   '난민',
#   '면접',
#   '당시',
#   '자신',
#   '이',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '10',
#   '.',
#   '납치',
#   '당하기',
#   '전',
#   '에는',
#   '그',
#   '누구',
#   '로부터',
#   '돈',
#   '을',
#   '달라',
#   '는',
#   '요구',
#   '를',
#   '받은',
#   '적',
#   '이',
#   '없다는',
#   '취지',
#   '로',
#   '진술',
#   '하였다',
#   '.',
#   '원고',
#   '는',
#   '난민',
#   '인정',
#   '신청서',
#   '에는',
#   '자신',
#   '이',
#   '저녁',
#   '경',
#   '에',
#   '납치',
#   '당하였다고',
#   '기재',
#   '한',
#   '반면',
#   ',',
#   '난민',
#   '면접',
#   '당시',
#   '에는',
#   '오전',
#   '9시',
#   '~',
#   '10시',
#   '사이',
#   '에',
#   '납치',
#   '당하였다고',
#   '진술',
#   '하였다',
#   '.',
#   '원고',
#   '는',
#   '위',
#   '난민',
#   '인정',
#   '신청서',
#   '에는',
#   '자신',
#   '이',
#   '납치',
#   '당하였을',
#   '때',
#   '납치',
#   '범',
#   '들',
#   '로부터',
#   '폭행',
#   '을',
#   '당하였다고',
#   '기재',
#   '하였으나',
#   ',',
#   '난민',
#   '면접',
#   '당시',
#   '에는',
#   '납치',
#   '범',
#   '들',
#   '로부터',
#   '폭행',
#   '을',
#   '당하지',
#   '않았다고',
#   '진술',
#   '을',
#   '번복',
#   '하였다',
#   '.',
#   '원고',
#   '는',
#   '난민',
#   '인정',
#   '신청서',
#   '에는',
#   '납치',
#   '범',
#   '들',
#   '로부터',
#   '풀려난',
#   '후',
#   '경찰서',
#   '에',
#   '위',
#   '사건',
#   '을',
#   '신고',
#   '하였으나',
#   '경찰',
#   '들',
#   '이',
#   '이를',
#   '접수',
#   '하지',
#   '않았고',
#   ',',
#   '위',
#   '신고',
#   '사실',
#   '을',
#   '알',
#   '게',
#   '된',
#   '납치',
#   '범',
#   '들',
#   '이',
#   '원고',
#   '에게',
#   '전화',
#   '를',
#   '하여',
#   '원고',
#   '를',
#   '살해',
#   '하겠다고',
#   '계속',
#   '적',
#   '으로',
#   '협박',
#   '하였다고',
#   '기재',
#   '한',
#   '반면',
#   '난민',
#   '면접',
#   '당시',
#   '에는',
#   '납치',
#   '범',
#   '들',
#   '로부터',
#   '풀려난',
#   '뒤',
#   '에',
#   '경찰',
#   '에',
#   '간',
#   '적도',
#   ',',
#   '경찰',
#   '을',
#   '만',
#   '나본',
#   '적도',
#   '없으며',
#   ',',
#   '대한민국',
#   '에',
#   '다시',
#   '귀국',
#   '할',
#   '때',
#   '까지',
#   '납치',
#   '범',
#   '들',
#   '로부터',
#   '추가',
#   '적',
#   '인',
#   '협박',
#   '등',
#   '을',
#   '받은',
#   '적',
#   '이',
#   '없다고',
#   '진술',
#   '을',
#   '번복',
#   '하였다',
#   '.',
#   '위',
#   '와',
#   '같이',
#   '원고',
#   '는',
#   '자신',
#   '의',
#   '납치',
#   '경위',
#   '와',
#   '관련',
#   '하여',
#   '①',
#   '납치',
#   '의',
#   '발단',
#   '이',
#   '된',
#   '금전',
#   '요구',
#   '가',
#   '언제',
#   '부터',
#   '있었는지',
#   ',',
#   '②',
#   '납치',
#   '시간',
#   ',',
#   '③',
#   '납치',
#   '당했을',
#   '당시',
#   '의',
#   '폭행',
#   '여부',
#   ',',
#   '④',
#   '납치',
#   '범',
#   '들',
#   '로부터',
#   '풀려난',
#   '후',
#   '경찰',
#   '에',
#   '신고',
#   '여부',
#   ',',
#   '⑤',
#   '납치',
#   '범',
#   '들',
#   '로부터',
#   '풀려난',
#   '후',
#   '추가',
#   '적',
#   '으로',
#   '협박',
#   '을',
#   '당했는지',
#   '여부',
#   '등',
#   '에',
#   '관',
#   '하여',
#   '진술',
#   '이',
#   '...'],
#  ['...',
#   '원고',
#   '의',
#   '행방',
#   '에',
#   '대해',
#   '묻다가',
#   '원고',
#   '의',
#   '동생',
#   '을',
#   '폭행',
#   '하기',
#   '시작',
#   '했다는',
#   '취지',
#   '의',
#   '고소장',
#   '(',
#   '갑',
#   '...',
#   '더',
#   '보기',
#   '...',
#   '소속',
#   '학생',
#   '들',
#   '에게',
#   '폭행',
#   '을',
#   '당하기까지',
#   '하였다',
#   '.',
#   '원고',
#   '는',
#   'B',
#   '를',
#   '탈퇴',
#   '하여',
#   '더',
#   '이상',
#   'B',
#   '활동',
#   '을',
#   '지속',
#   '하고',
#   '있지',
#   '않는데도',
#   'IJT',
#   '소속',
#   '학생',
#   '들',
#   '은',
#   '원고',
#   '의',
#   '말',
#   '을',
#   '믿지',
#   '않고',
#   '원고',
#   '가',
#   'B',
#   '활동',
#   '을',
#   '계속',
#   '하고',
#   '있다고',
#   '주장',
#   '하며',
#   '원고',
#   '에게',
#   '위해',
#   '를',
#   '가하려고',
#   '하고',
#   '있다',
#   '.',
#   '이처럼',
#   '원고',
#   '는',
#   '정치',
#   '적',
#   '의견',
#   '을',
#   '이유',
#   '로',
#   'IJT',
#   '로부터',
#   '박해',
#   '를',
#   '받고',
#   '있으므로',
#   '난민',
#   '에',
#   '해당',
#   '한',
#   '다',
#   '고',
#   '보아',
#   '야',
#   '하는데도',
#   '피고',
#   '는',
#   '이',
#   '와',
#   '달리',
#   '판단',
#   '하였으므로',
#   '이',
#   '사건',
#   '처분',
#   '은',
#   '위법',
#   '하다',
#   '.',
#   '관계',
#   '법령',
#   '별',
#   '지',
#   '기재',
#   '와',
#   '같다',
#   '.',
#   '판',
#   '단',
#   '난민',
#   '인정',
#   '의',
#   '요건',
#   '이',
#   '되는',
#   '‘',
#   '박해',
#   '를',
#   '받을',
#   '충분한',
#   '근거',
#   '있는',
#   '공포',
#   '’',
#   '의',
#   '존부',
#   '에',
#   '대한',
#   '증명책임',
#   '은',
#   '난민',
#   '인정',
#   '신청',
#   '을',
#   '하는',
#   '외국인',
#   '에게',
#   '있다',
#   '(',
#   '대법원',
#   '2008',
#   '.',
#   '7',
#   '.',
#   '24',
#   '.',
#   '선고',
#   '2007',
#   '두',
#   '19539',
#   '판결',
#   '참조',
#   ').',
#   '원고',
#   '는',
#   '자신',
#   '이',
#   'B',
#   '의',
#   '지역',
#   '서기장',
#   '으로',
#   '임명',
#   '되었다는',
#   '취지',
#   '의',
#   '자료',
#   '(',
#   '갑',
#   '제',
#   '5',
#   '호증',
#   ')',
#   '및',
#   'IJT',
#   '소속',
#   '학생',
#   '들',
#   '이',
#   '원고',
#   '의',
#   '동생',
#   '에게',
#   '원고',
#   '의',
#   '행방',
#   '에',
#   '대해',
#   '묻다가',
#   '원고',
#   '의',
#   '동생',
#   '을',
#   '폭행',
#   '하기',
#   '시작',
#   '했다는',
#   '취지',
#   '의',
#   '고소장',
#   '(',
#   '갑',
#   '제',
#   '4',
#   '호증',
#   ')',
#   '을',
#   '제출',
#   '하고',
#   '있을',
#   '뿐',
#   ',',
#   'IJT',
#   '라는',
#   '단체',
#   '가',
#   '실제',
#   '로',
#   '존재',
#   '하는지',
#   ',',
#   'IJT',
#   '가',
#   'B',
#   '소속',
#   '학생',
#   '들',
#   '을',
#   '표적',
#   '으로',
#   '하여',
#   '폭행',
#   'ㆍ',
#   '협박',
#   '등',
#   '을',
#   '가하고',
#   '있는지',
#   ',',
#   '파키스탄',
#   '치안',
#   '당국',
#   '이',
#   'IJT',
#   '에',
#   '의한',
#   '폭행',
#   '등',
#   '을',
#   '예방',
#   '할',
#   '의지',
#   '와',
#   '능력',
#   '이',
#   '없는지',
#   '여부',
#   '등',
#   '에',
#   '관해',
#   '아무런',
#   '자료',
#   '를',
#   '제출',
#   '하지',
#   '않고',
#   '있다',
#   '.',
#   '그리고',
#   '위',
#   '갑',
#   '제',
#   '5',
#   '호증',
#   '은',
#   '단지',
#   '원고',
#   '가',
#   'B',
#   '의',
#   '지역',
#   '서기장',
#   '에',
#   '임명',
#   '되었다는',
#   '취지',
#   '에',
#   '불과하고',
#   ',',
#   '갑',
#   '제',
#   '4',
#   '호증',
#   '은',
#   '원고',
#   '의',
#   '동생',
#   '의',
#   '일방',
#   '적',
#   '진술',
#   '을',
#   '담은',
#   '고소장',
#   '에',
#   '불과하므로',
#   ',',
#   '원고',
#   '가',
#   '제출',
#   '한',
#   '위',
#   '자료',
#   '만으로',
#   '원고',
#   '에게',
#   '정치',
#   '적',
#   '의견',
#   '을',
#   '이유',
#   '로',
#   '한',
#   '박해',
#   '의',
#   '위험',
#   '이',
#   '있다고',
#   '보기',
#   '부족하다',
#   '.',
#   '오히려',
#   ',',
#   '을',
#   '제',
#   '4',
#   '호증',
#   '의',
#   '기재',
#   '에',
#   '변론',
#   '전체',
#   '의',
#   '취지',
#   '를',
#   '종합',
#   '하면',
#   ',',
#   '파키스탄',
#   '의',
#   '북서',
#   '국경',
#   '지대',
#   '및',
#   '카라치',
#   '시를',
#   '제외',
#   '한',
#   '다른',
#   '지역',
#   '(',
#   '원고',
#   '가',
#   '거주',
#   '하는',
#   '펀잡',
#   '주',
#   '를',
#   '포함',
#   '한다',
#   ')',
#   '은',
#   '상대',
#   '적',
#   '으로',
#   '치안',
#   '이',
#   '호전',
#   '되고',
#   '있는',
#   '사실',
#   ',...'],
#  ['....',
#   '③',
#   '원고',
#   '는',
#   '수니파',
#   '폭력단',
#   '체인',
#   '자맛',
#   '-',
#   '울',
#   '...',
#   '조',
#   '직원',
#   '들',
#   '의',
#   '위협',
#   '과',
#   '폭행',
#   '이',
#   '원고',
#   '의',
#   '종교',
#   '를',
#   '...',
#   '더',
#   '보기',
#   '...',
#   '이',
#   '사건',
#   '난민',
#   '신청',
#   '을',
#   '한',
#   '것',
#   '은',
#   '아닌지',
#   '그',
#   '동기',
#   '가',
#   '의심',
#   '된다',
#   '.',
#   '②',
#   '원고',
#   '는',
#   '대한민국',
#   '에',
#   '입국',
#   '한',
#   '후',
#   '부터',
#   '이',
#   '사건',
#   '난민',
#   '신청',
#   '전',
#   '까지',
#   '대명',
#   '세라믹',
#   '주식회사',
#   ',',
#   '삼화',
#   '양행',
#   '주식회사',
#   '등',
#   '에서',
#   '계속',
#   '경제활동',
#   '을',
#   '하였고',
#   ',',
#   '난민',
#   '면',
#   '접시',
#   '“',
#   '2000년',
#   '에',
#   '대학',
#   '을',
#   '졸업',
#   '한',
#   '후',
#   '파키스탄',
#   '에서',
#   '일자리',
#   '를',
#   '구',
#   '하기',
#   '위해',
#   '노력',
#   '했으나',
#   '일자리',
#   '가',
#   '없었다',
#   '.',
#   '한국',
#   '에',
#   '일',
#   '하러',
#   '왔다',
#   '”',
#   '고',
#   '진술',
#   '한',
#   '사정',
#   '등',
#   '에',
#   '비추어',
#   '볼',
#   '때',
#   ',',
#   '원고',
#   '는',
#   '경제',
#   '적',
#   '인',
#   '목적',
#   '으로',
#   '대한민국',
#   '에',
#   '체류',
#   '하고자',
#   '하는',
#   '것',
#   '으로',
#   '보인다',
#   '.',
#   '③',
#   '원고',
#   '는',
#   '수니파',
#   '폭력단',
#   '체인',
#   '자맛',
#   '-',
#   '울',
#   '-',
#   '다',
#   '와로',
#   '부터',
#   '원고',
#   '가',
#   '시아파',
#   '라는',
#   '이유',
#   '로',
#   '박해',
#   '를',
#   '당할',
#   '위험',
#   '이',
#   '있다고',
#   '주',
#   '장하나',
#   ',',
#   '원고',
#   '의',
#   '가족',
#   '이',
#   '1980',
#   '.',
#   '경',
#   '부터',
#   '이',
#   '사건',
#   '위협',
#   '이',
#   '있은',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '경',
#   '까지',
#   '약',
#   '32년',
#   '동안',
#   '같은',
#   '마을',
#   '에서',
#   '살았음에도',
#   'D',
#   '및',
#   '자맛',
#   '-',
#   '알',
#   '-',
#   '다',
#   '와',
#   '조',
#   '직원',
#   '들',
#   '로부터',
#   '아무런',
#   '위협',
#   '을',
#   '받지',
#   '않았고',
#   ',',
#   '위',
#   '조',
#   '직원',
#   '들',
#   '은',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '4',
#   '.',
#   '과',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '11',
#   '.',
#   '원고',
#   '의',
#   '집',
#   '을',
#   '찾아와',
#   '돈',
#   '을',
#   '내놓으라며',
#   '협박',
#   '하였으므로',
#   '[',
#   '원고',
#   '는',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '4',
#   '.',
#   '의',
#   '협박',
#   '내용',
#   '에',
#   '관',
#   '하여',
#   '난민',
#   '면',
#   '접시',
#   '에는',
#   '“',
#   '종교',
#   '행사',
#   '를',
#   '하면',
#   '죽이겠다',
#   '”',
#   '는',
#   '내용',
#   '이었다고',
#   '진술',
#   '하였다가',
#   ',',
#   '이',
#   '사건',
#   '제',
#   '1회',
#   '변론기일',
#   '에',
#   '제출',
#   '한',
#   '질문지',
#   '(',
#   '갑',
#   '제',
#   '4',
#   '호증',
#   ')',
#   '에는',
#   '“',
#   '돈',
#   '을',
#   '내놓지',
#   '않으면',
#   '죽이겠다',
#   '”',
#   '는',
#   '내용',
#   '이라고',
#   '기재',
#   '하였다',
#   '],',
#   '위',
#   '조',
#   '직원',
#   '들',
#   '의',
#   '위협',
#   '과',
#   '폭행',
#   '이',
#   '원고',
#   '의',
#   '종교',
#   '를',
#   '이유',
#   '로',
#   '이루어졌다고',
#   '보기',
#   '어렵다',
#   '.',
#   '④',
#   '원고',
#   '의',
#   '진술',
#   '에',
#   '의하더라도',
#   ',',
#   '난민',
#   '면접',
#   '일인',
#   '2014',
#   '.',
#   '2',
#   '.',
#   '21',
#   '.',
#   '현재',
#   '원고',
#   '의',
#   '가족',
#   '들',
#   '이',
#   '안전한',
#   '곳',
#   '으로',
#   '이주',
#   '하기',
#   '위',
#   '한',
#   '준비',
#   '를',
#   '하고',
#   '있었고',
#   ',',
#   '원고',
#   '스스로',
#   '1년',
#   '정도',
#   '기간',
#   '을',
#   '준다면',
#   '파키스탄',
#   '으로',
#   '돌아가겠다고',
#   '하였으므로',
#   ',',
#   '원고',
#   '가',
#   '파키스탄',
#   '으로',
#   '돌아가더라도',
#   '원고',
#   '에게',
#   '위협',
#   '을',
#   '가한',
#   '주체',
#   '들',
#   '의',
#   '영향',
#   '이',
#   '미치지',
#   '않는',
#   '곳',
#   '으로',
#   '피신',
#   '하여',
#   '안전하게',
#   '지낼',
#   '수',
#   '있을',
#   '것',
#   '으로',
#   '보인다',
#   '.',
#   '⑤',
#   '주',
#   '(',
#   '駐',
#   ')',
#   '파키스탄',
#   '한국',
#   '대사관',
#   '은',
#   '파키스탄',
#   '국민',
#   '이',
#   '...'],
#  ['...',
#   '길',
#   '에',
#   '마을',
#   '에서',
#   '모르는',
#   '사람',
#   '으로부터',
#   '폭행',
#   '을',
#   '당하였다',
#   '.',
#   '원고',
#   '는',
#   '계속',
#   '폭행',
#   '당하다가',
#   '...',
#   '더',
#   '보기',
#   '....',
#   '4',
#   '.',
#   '9',
#   '.',
#   '작성',
#   ',',
#   '갑',
#   '제',
#   '3',
#   '호증',
#   ')',
#   '전임',
#   '족장',
#   '인',
#   '원고',
#   '의',
#   '부친',
#   '이',
#   '사망',
#   '했을',
#   '때',
#   ',',
#   '장자',
#   '인',
#   '원고',
#   '가',
#   '아직',
#   '십대',
#   '로서',
#   '통치',
#   '연령',
#   '에',
#   '이르지',
#   '않아',
#   '족장',
#   '직',
#   '을',
#   '승계',
#   '할',
#   '수',
#   '없어서',
#   ',',
#   '조',
#   '상신',
#   '들',
#   '의',
#   '‘',
#   '메신저',
#   '’',
#   '를',
#   '통해',
#   '승계',
#   '가',
#   '결정',
#   '될',
#   '때',
#   '까지',
#   '족장',
#   '직',
#   '은',
#   '원고',
#   '의',
#   '삼촌',
#   '(',
#   'B',
#   ')',
#   '에게',
#   '임시',
#   '로',
#   '맡겨졌다',
#   '.',
#   '원고',
#   '의',
#   '삼촌',
#   '은',
#   '원고',
#   '의',
#   '모친',
#   '을',
#   '협박',
#   '하여',
#   '원고',
#   '로',
#   '하여금',
#   '족장',
#   '직',
#   '승계',
#   '를',
#   '포기',
#   '하게',
#   '하라',
#   '고',
#   '하였고',
#   ',',
#   '모친',
#   '역시',
#   '원고',
#   '에게',
#   '족장',
#   '직',
#   '을',
#   '포기',
#   '하',
#   '라고',
#   '하였지만',
#   '그것',
#   '은',
#   '원고',
#   '의',
#   '‘',
#   '생득',
#   '권',
#   '’',
#   '이었기에',
#   '포기',
#   '할',
#   '수',
#   '없었다',
#   '.',
#   '원고',
#   '가',
#   '삼촌',
#   '에게',
#   '대항',
#   '하자',
#   '삼촌',
#   '은',
#   '그',
#   '의',
#   '능력',
#   '을',
#   '보여주기',
#   '위해',
#   '원고',
#   '의',
#   '남동생',
#   '을',
#   '납치',
#   '하였고',
#   ',',
#   '경찰',
#   '에',
#   '신고',
#   '하였지만',
#   '경찰',
#   '조사',
#   '는',
#   '시작',
#   '되자마자',
#   '끝났다',
#   '.',
#   '삼촌',
#   '이',
#   '원고',
#   '지역',
#   '의',
#   '시장',
#   '(',
#   'Lord',
#   'Mayor',
#   ')',
#   '과',
#   '긴밀하게',
#   '연관',
#   '되어',
#   '영향력',
#   '을',
#   '행사',
#   '했기',
#   '때문',
#   '이다',
#   '.',
#   '얼마',
#   '후',
#   '원고',
#   '는',
#   '퇴근',
#   '하던',
#   '길',
#   '에',
#   '마을',
#   '에서',
#   '모르는',
#   '사람',
#   '으로부터',
#   '폭행',
#   '을',
#   '당하였다',
#   '.',
#   '원고',
#   '는',
#   '계속',
#   '폭행',
#   '당하다가',
#   '원고',
#   '의',
#   '족장',
#   '즉위',
#   '식',
#   '예정일',
#   '(',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '29',
#   '.)',
#   '보다',
#   '며칠',
#   '앞선',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '26',
#   '.',
#   '에',
#   '납치',
#   '당하여',
#   '약',
#   '4',
#   '개월',
#   '만에',
#   '풀려',
#   '났다',
#   '.',
#   '나',
#   ')',
#   '난민',
#   '면접',
#   '조서',
#   '(',
#   '2014',
#   '.',
#   '4',
#   '.',
#   '3',
#   '.',
#   '작성',
#   ',',
#   '을',
#   '제',
#   '3',
#   '호증',
#   ')',
#   '원고',
#   '는',
#   '카메룬',
#   '남',
#   '서부',
#   '만유',
#   '지역',
#   '의',
#   '바',
#   '양',
#   '기',
#   '족',
#   '으로서',
#   'C',
#   '마을',
#   '족장',
#   '인',
#   '부친',
#   '의',
#   '장자',
#   '로',
#   '태어났는데',
#   ',',
#   '2010년',
#   '부터',
#   '2013년',
#   '까지',
#   '‘',
#   'D',
#   '’',
#   '이라는',
#   '회사',
#   '에서',
#   '일',
#   '하다가',
#   '현재',
#   '의',
#   '족장',
#   '인',
#   '원고',
#   '삼촌',
#   '의',
#   '박해',
#   '를',
#   '피',
#   '하기',
#   '위',
#   '하여',
#   '대학교',
#   '선배',
#   'E',
#   '가',
#   '소개',
#   '해준',
#   '에이전트',
#   '에게',
#   '1,000달러',
#   '를',
#   '지불',
#   '하고',
#   '한국',
#   '사증',
#   '을',
#   '발급',
#   '받아',
#   '출국',
#   '하였다',
#   '.',
#   '원고',
#   '의',
#   '삼촌',
#   '이',
#   '사주',
#   '한',
#   '4',
#   '명의',
#   '남자',
#   '가',
#   '2012',
#   '.',
#   '5',
#   '.',
#   '26',
#   '.',
#   '원고',
#   '의',
#   '집',
#   '으로',
#   '찾아와',
#   '원고',
#   '를',
#   '끌',
#   '고',
#   '두알라',
#   '인근',
#   '의',
#   '버려진',
#   '빌딩',
#   '으로',
#   '데려가',
#   '“',
#   '족장',
#   '이',
#   '되지',
#   '말라',
#   '”',
#   '고',
#   '하면서',
#   '원고',
#   '를',
#   '구타',
#   '한',
#   '후',
#   '재갈',
#   '을',
#   '물리',
#   '고',
#   '묶인',
#   '상태',
#   '로',
#   '버려',
#   '두었다',
#   '.',
#   '원고',
#   '는',
#   '5일',
#   '간',
#   '버려져',
#   '있다가',
#   '어떤',
#   '여성',
#   '에게',
#   '발견',
#   '되어',
#   '가까운',
#   '파출소',
#   '로',
#   '가게',
#   '...']]

# %%
len(reason)
# Out:
# 12290

# %%
tokens = [t for d in reason for t in d]
reason_seri = law_df['이유토큰화']
tokens_seri = [t for d in reason_seri for t in d]
tokens_seri2 = [d for d in reason_seri]

reason_seri[:10]
# Out:
# 0    [('...', 'Punctuation'), ('위해', 'Noun'), ('거짓말...
# 1    [('...,', 'Punctuation'), ('이하', 'Noun'), ('‘'...
# 2    [('...', 'Punctuation'), ('치료', 'Noun'), ('를',...
# 3    [('...', 'Punctuation'), ('위', 'Noun'), ('와', ...
# 4    [('...', 'Punctuation'), ('길', 'Noun'), ('에', ...
# 5    [('...', 'Punctuation'), ('2013', 'Number'), (...
# 6    [('...,', 'Punctuation'), ('난민', 'Noun'), ('면접...
# 7    [('...', 'Punctuation'), ('원고', 'Noun'), ('의',...
# 8    [('....', 'Punctuation'), ('③', 'Foreign'), ('...
# 9    [('...', 'Punctuation'), ('길', 'Noun'), ('에', ...
# Name: 이유토큰화, dtype: object

# %%
print(tokens_seri[:10])
print(len(tokens_seri))
print(tokens_seri2[:2])
print(len(tokens_seri2))
print(tokens[:10])
print(len(tokens))

# 왜인지는 모르겠으나, 데이터프레임에 있던 시리즈를 들고와서 처리하면 원치않는 형식으로 변함.
# Out:
# ['[', '(', "'", '.', '.', '.', "'", ',', ' ', "'"]
# 85505041
# ["[('...', 'Punctuation'), ('위해', 'Noun'), ('거짓말', 'Noun'), ('을', 'Josa'), ('하자', 'Noun'), ('어머니', 'Noun'), ('와', 'Josa'), ('처', 'Noun'), ('에게', 'Josa'), ('폭행', 'Noun'), ('을', 'Josa'), ('가하였다', 'Verb'), ('.', 'Punctuation'), ('이', 'Noun'), ('에', 'Josa'), ('원고', 'Noun'), ('가', 'Josa'), ('화가', 'Noun'), ('나', 'Noun'), ('칼', 'Noun'), ('을', 'Josa'), ('...', 'Punctuation'), ('더', 'Noun'), ('보기', 'Noun'), ('...', 'Punctuation'), ('이유', 'Noun'), ('로', 'Josa'), ('카메룬', 'Noun'), ('경찰', 'Noun'), ('에', 'Josa'), ('의해', 'Adjective'), ('구속', 'Noun'), ('되었다', 'Verb'), ('.', 'Punctuation'), ('원고', 'Noun'), ('는', 'Josa'), ('삼촌', 'Noun'), ('의', 'Josa'), ('부탁', 'Noun'), ('으로', 'Josa'), ('삼촌', 'Noun'), ('집', 'Noun'), ('에', 'Josa'), ('있던', 'Adjective'), ('반정부', 'Noun'), ('성향', 'Noun'), ('의', 'Josa'), ('책자', 'Noun'), ('를', 'Josa'), ('자신', 'Noun'), ('의', 'Josa'), ('집', 'Noun'), ('에', 'Josa'), ('숨겼는데', 'Verb'), (',', 'Punctuation'), ('이를', 'Verb'), ('이유', 'Noun'), ('로', 'Josa'), ('경찰', 'Noun'), ('에', 'Josa'), ('의해', 'Adjective'), ('체포', 'Noun'), ('당', 'Suffix'), ('한', 'Josa'), ('적', 'Noun'), ('이', 'Josa'), ('있고', 'Adjective'), (',', 'Punctuation'), ('2005', 'Number'), ('.', 'Punctuation'), ('경', 'Noun'), ('삼촌', 'Noun'), ('의', 'Josa'), ('부탁', 'Noun'), ('으로', 'Josa'), ('SCNC', 'Alpha'), ('가입', 'Noun'), ('을', 'Josa'), ('홍보', 'Noun'), ('하는', 'Verb'), ('내용', 'Noun'), ('의', 'Josa'), ('전단지', 'Noun'), ('를', 'Josa'), ('배포', 'Noun'), ('하기도', 'Verb'), ('하였다', 'Verb'), ('.', 'Punctuation'), ('이', 'Noun'), ('와', 'Josa'), ('같이', 'Adverb'), ('카메룬', 'Noun'), ('정부', 'Noun'), ('는', 'Josa'), ('SCNC', 'Alpha'), ('회원', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('체포', 'Noun'), ('하는', 'Verb'), ('등', 'Noun'), ('박해', 'Noun'), ('하고', 'Josa'), ('있는바', 'Adjective'), (',', 'Punctuation'), ('원고', 'Noun'), ('는', 'Josa'), ('SCNC', 'Alpha'), ('회원', 'Noun'), ('이', 'Josa'), ('아님에도', 'Adjective'), ('카메룬', 'Noun'), ('정부', 'Noun'), ('로부터', 'Noun'), ('SCNC', 'Alpha'), ('회원', 'Noun'), ('으로', 'Josa'), ('오인', 'Noun'), ('을', 'Josa'), ('받고', 'Verb'), ('있다', 'Adjective'), ('(', 'Punctuation'), ('이하', 'Noun'), ('’', 'Punctuation'), ('제', 'Noun'), ('1', 'Number'), ('사유', 'Noun'), ('‘', 'Foreign'), ('라고', 'Josa'), ('한다', 'Verb'), (').', 'Punctuation'), ('2', 'Number'), (')', 'Punctuation'), ('2011', 'Number'), ('.', 'Punctuation'), ('5', 'Number'), ('.', 'Punctuation'), ('경', 'Noun'), ('축구장', 'Noun'), ('에서', 'Josa'), ('선거', 'Noun'), ('유세', 'Noun'), ('를', 'Josa'), ('하던', 'Verb'), ('사람과', 'Noun'), ('축구', 'Noun'), ('를', 'Josa'), ('하던', 'Verb'), ('사람', 'Noun'), ('들', 'Suffix'), ('사이', 'Noun'), ('에', 'Josa'), ('다툼', 'Noun'), ('이', 'Josa'), ('생겼는데', 'Verb'), (',', 'Punctuation'), ('원고', 'Noun'), ('는', 'Josa'), ('그', 'Noun'), ('싸움', 'Noun'), ('에', 'Josa'), ('관여', 'Noun'), ('하지', 'Verb'), ('않았었다', 'Verb'), ('.', 'Punctuation'), ('그런데', 'Conjunction'), ('경찰', 'Noun'), ('은', 'Josa'), ('위', 'Noun'), ('폭행', 'Noun'), ('사건', 'Noun'), ('의', 'Josa'), ('용의자', 'Noun'), ('로', 'Josa'), ('원고', 'Noun'), ('를', 'Josa'), ('지목', 'Noun'), ('한', 'Josa'), ('다음', 'Noun'), ('원고', 'Noun'), ('를', 'Josa'), ('체포', 'Noun'), ('하기', 'Verb'), ('위', 'Noun'), ('하여', 'Verb'), ('원고', 'Noun'), ('의', 'Josa'), ('집', 'Noun'), ('에', 'Josa'), ('찾아왔는데', 'Verb'), (',', 'Punctuation'), ('원고', 'Noun'), ('의', 'Josa'), ('어머니', 'Noun'), ('와', 'Josa'), ('처가', 'Noun'), ('원고', 'Noun'), ('를', 'Josa'), ('숨기기', 'Verb'), ('위해', 'Noun'), ('거짓말', 'Noun'), ('을', 'Josa'), ('하자', 'Noun'), ('어머니', 'Noun'), ('와', 'Josa'), ('처', 'Noun'), ('에게', 'Josa'), ('폭행', 'Noun'), ('을', 'Josa'), ('가하였다', 'Verb'), ('.', 'Punctuation'), ('이', 'Noun'), ('에', 'Josa'), ('원고', 'Noun'), ('가', 'Josa'), ('화가', 'Noun'), ('나', 'Noun'), ('칼', 'Noun'), ('을', 'Josa'), ('이용', 'Noun'), ('해', 'Verb'), ('경찰관', 'Noun'), ('1', 'Number'), ('명', 'Noun'), ('을', 'Josa'), ('살해', 'Noun'), ('하였다', 'Verb'), ('(', 'Punctuation'), ('이하', 'Noun'), ('‘', 'Foreign'), ('제', 'Noun'), ('2', 'Number'), ('사유', 'Noun'), ('’', 'Punctuation'), ('라고', 'Josa'), ('한다', 'Verb'), (').', 'Punctuation'), ('3', 'Number'), (')',  ...
# 12290
# ['...', '위해', '거짓말', '을', '하자', '어머니', '와', '처', '에게', '폭행']
# 5028837

# %%
text = nltk.Text(tokens, name='NMSC')

print(len(text.tokens)) # 전체 토큰의 개수
print(len(set(text.tokens))) # 중복 제외한 토큰의 개수
pprint(text.vocab().most_common(10)) # 출현 빈도가 높은 상위 토큰 10개
# Out:
# 5028837
# 52470
# [('.', 243249),
#  (',', 163773),
#  ('의', 150884),
#  ('을', 122552),
#  ('에', 108494),
#  ('이', 105049),
#  ('원고', 102568),
#  ('를', 82041),
#  ('가', 68589),
#  ('는', 56204)]

# %%
plt.figure(figsize=(30,10))
text.plot(50)

# %%
X_data = reason
y_data = law_df['승소여부'].to_list()

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X_data, y_data, test_size=0.25, random_state=42)

# %%
selected_words = [f[0] for f in text.vocab().most_common(10000)]

def term_frequency(doc):
    return [doc.count(word) for word in selected_words]

train_x = [term_frequency(d) for d in X_train]
test_x = [term_frequency(d) for d in X_test]
train_y = [c for c in y_train]
test_y = [c for c in y_test]

# %%
len(train_x[0])
# Out:
# 10000

# %%
XX_train = np.asarray(train_x).astype('float32')
XX_test = np.asarray(test_x).astype('float32')

yy_train = np.asarray(train_y).astype('float32')
yy_test = np.asarray(test_y).astype('float32')

# %%
XX_train.shape, XX_test.shape, yy_train.shape, yy_test.shape
# Out:
# ((9217, 10000), (3073, 10000), (9217,), (3073,))

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
             loss=losses.binary_crossentropy,
             metrics=[metrics.binary_accuracy])

model.fit(XX_train, yy_train, epochs=10, batch_size=512)
results = model.evaluate(XX_test, yy_test)
# Out:
# Epoch 1/10
# 19/19 [==============================] - 1s 44ms/step - loss: 0.5582 - binary_accuracy: 0.6924
# Epoch 2/10
# 19/19 [==============================] - 1s 27ms/step - loss: 0.4287 - binary_accuracy: 0.7855
# Epoch 3/10
# 19/19 [==============================] - 0s 25ms/step - loss: 0.3666 - binary_accuracy: 0.8306
# Epoch 4/10
# 19/19 [==============================] - 0s 25ms/step - loss: 0.3291 - binary_accuracy: 0.8454
# Epoch 5/10
# 19/19 [==============================] - 0s 23ms/step - loss: 0.2800 - binary_accuracy: 0.8765
# Epoch 6/10
# 19/19 [==============================] - 0s 24ms/step - loss: 0.2354 - binary_accuracy: 0.8999
# Epoch 7/10
# 19/19 [==============================] - 0s 26ms/step - loss: 0.1926 - binary_accuracy: 0.9239
# Epoch 8/10
# 19/19 [==============================] - 0s 26ms/step - loss: 0.1827 - binary_accuracy: 0.9242
# Epoch 9/10
# 19/19 [==============================] - 2s 88ms/step - loss: 0.1296 - binary_accuracy: 0.9549
# Epoch 10/10
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1180 - binary_accuracy: 0.9563
# 97/97 [==============================] - 0s 2ms/step - loss: 1.0842 - binary_accuracy: 0.6827

# %%
results
# Out:
# [1.084192156791687, 0.6827204823493958]

# %%
def tokenize(writing):
    return ['/'.join(t) for t in okt.pos(writing, norm=True, stem=True)]

# %%
def predict_pos_neg(review):

    token = tokenize(review)
    tf = term_frequency(token)
    data = np.expand_dims(np.asarray(tf).astype('float32'), axis=0)
    score = float(model.predict(data))
    if(score > 0.5):
        print("[{}]는 {:.2f}% 확률로 승소이지 않을까 추측해봅니다.^^\n".format(review, score * 100))
    else:
        print("[{}]는 {:.2f}% 확률로 패소이지 않을까 추측해봅니다.^^;\n".format(review, (1 - score) * 100))

# %%
predict_pos_neg('올해 최고의 영화! 세 번 넘게 봐도 질리지가 않네요.')
# Out:
# [올해 최고의 영화! 세 번 넘게 봐도 질리지가 않네요.]는 51.05% 확률로 승소이지 않을까 추측해봅니다.^^

# %%
predict_pos_neg('기복과 근거 없는 부정행위 의심, 폭언, 폭행을 주장한 사실이 인정된다. 그러나, 위와... 더보기 ... 따라서 피고는 원고에게 불법행위에 기한 손해배상으로 위자료 1,700만 원 및 이에 대하여 이 사건 소장 부본 송달 다음날인 2019. 11. 7.부터(원고는 불법행위의 시기인 2019. 9. 10.부터 지연손해금의 지급을 구한다고 주장하나, 원고의 청구는 부정행위 기간 전체에 대한 위자료 청구이고, 종기에 대한 주장, 입증이 없으므로, 이 사건 소장 부본 송달 다음날부터 지연손해금의 지급을 명한다) 이 판결 선고일인 2020. 10. 7.까지는 민법이 정한 연 5%, 그 다음날부터 다 갚는 날까지는 소송촉진 등에 관한 특례법이 정한 연 12%의 각 비율로 계산한 지연손해금을 지급할 의무가 있다. 3. 피고의 주장에 대한 판단 가. 주장의 요지 C와 원고의 혼인관계는 2019. 8.경부터 파탄 상태였다. 따라서, 피고와 C의 행위가 원고의 부부공동생활을 침해하거나 유지를 방해하였다고 할 수 없다. 나. 판단 을 제7호증, 갑 제11호증, 변론 전체의 취지를 종합하면, C가 2019. 10. 30. 인천가정법원 2019너16027호(2019드단115082호로 접수되었다가 재배당되었다)로 원고에 대하여 이혼 및 위자료 2,000만 원 지급을 구하는 조정신청을 한 사실, C는 신청원인으로 원고의 감정 기복과 근거 없는 부정행위 의심, 폭언, 폭행을 주장한 사실이 인정된다. 그러나, 위와 같은 사정만으로는 피고와 C의 부정행위 당시 이미 원고와 C의 부부공동생활이 실질적으로 파탄되어 실체가 더 이상 존재하지 아니하게 되고 객관적으로 회복할 수 없는 정도에 이르렀다고 보기에 부족하고 달리 이를 인정할 증거가 없다. 따라서, 피고의 주장은 이유 없다. 4. 결론 원고의 청구는 위 인정범위 내에서 이유 있으므로 이를 인용하고, 나머지 청구는 이유 없으므로 이를 기각하기로 하여 주문과 같이 판결한다')
# Out:
# [기복과 근거 없는 부정행위 의심, 폭언, 폭행을 주장한 사실이 인정된다. 그러나, 위와... 더보기 ... 따라서 피고는 원고에게 불법행위에 기한 손해배상으로 위자료 1,700만 원 및 이에 대하여 이 사건 소장 부본 송달 다음날인 2019. 11. 7.부터(원고는 불법행위의 시기인 2019. 9. 10.부터 지연손해금의 지급을 구한다고 주장하나, 원고의 청구는 부정행위 기간 전체에 대한 위자료 청구이고, 종기에 대한 주장, 입증이 없으므로, 이 사건 소장 부본 송달 다음날부터 지연손해금의 지급을 명한다) 이 판결 선고일인 2020. 10. 7.까지는 민법이 정한 연 5%, 그 다음날부터 다 갚는 날까지는 소송촉진 등에 관한 특례법이 정한 연 12%의 각 비율로 계산한 지연손해금을 지급할 의무가 있다. 3. 피고의 주장에 대한 판단 가. 주장의 요지 C와 원고의 혼인관계는 2019. 8.경부터 파탄 상태였다. 따라서, 피고와 C의 행위가 원고의 부부공동생활을 침해하거나 유지를 방해하였다고 할 수 없다. 나. 판단 을 제7호증, 갑 제11호증, 변론 전체의 취지를 종합하면, C가 2019. 10. 30. 인천가정법원 2019너16027호(2019드단115082호로 접수되었다가 재배당되었다)로 원고에 대하여 이혼 및 위자료 2,000만 원 지급을 구하는 조정신청을 한 사실, C는 신청원인으로 원고의 감정 기복과 근거 없는 부정행위 의심, 폭언, 폭행을 주장한 사실이 인정된다. 그러나, 위와 같은 사정만으로는 피고와 C의 부정행위 당시 이미 원고와 C의 부부공동생활이 실질적으로 파탄되어 실체가 더 이상 존재하지 아니하게 되고 객관적으로 회복할 수 없는 정도에 이르렀다고 보기에 부족하고 달리 이를 인정할 증거가 없다. 따라서, 피고의 주장은 이유 없다. 4. 결론 원고의 청구는 위 인정범위 내에서 이유 있으므로 이를 인용하고, 나머지 청구는 이유 없으므로 이를 기각하기로 하여 주문과 같이 판결한다]는 51.05% 확률로 승소이지 않을까 추측해봅니다.^^

# %%
predict_pos_neg('따르면, 원고는 다음과 같이 B로부터 폭행당한 경위를 설명하고 있다. “술에 취한 B가... 더보기 ... 있다고 보아야 한다. 나. 관계법령 산업재해보상보험법 제5조(정의) 이 법에서 사용하는 용어의 뜻은 다음과 같다. 1. “업무상의 재해”란 업무상의 사유에 따른 근로자의 부상질병장해 또는 사망을 말한다. 제49조(추가상병 요양급여의 신청) 업무상의 재해로 요양 중인 근로자는 다음 각 호의 어느 하나에 해당하는 경우에는 그 부상 또는 질병(이하, “추가상병”이라 한다.)에 대한 요양급여를 신청할 수 있다. 1. 그 업무상의 재해로 이미 발생한 부상이나 질병이 추가로 발견되어 요양이 필요한 경우 2. 그 업무상의 재해로 발생한 부상이나 질병이 원인이 되어 새로운 질병이 발생하여 요양이 필요한 경우 다. 인정사실 (1) 이 사건 재해의 내용에 관한 원고의 진술 2012. 2. 17.자 피고 담당공무원 작성의 문답서(갑 제5호증)에 따르면, 원고는 다음과 같이 B로부터 폭행당한 경위를 설명하고 있다. “술에 취한 B가 원고의 목부위에 휴대전화기를 던졌고, 오른손으로 턱을 가격하였다. 주변에서 사람들이 말려서 분을 삭이기 위하여 의자에 앉아 있었는데, B가 다가와 쓰레기통 뚜껑으로 원고를 때렸다. 이후 발인지 손인지 잘 모르겠으나 등을 맞았고, 의자에서 떨어져 땅바닥에 주저앉아 있을 때 발로도 밟힌 것 같다. B로부터 맞은 부위는 목, 오른쪽 턱, 등, 허리 쪽이다. 예전에 허리부위에 수술을 2번 받은 적이 있는데 이 사건 이후 병원에 가 보았더니 옛날 수술부위는 괜찮은데 그 윗부분에 이상이 생겼다고 하였다.” (2) 원고의 이 사건 재해 이전의 치료내역 원고는 2001. 6.경부터 요추부통증 및 제4-5요추-제1천추간 퇴행성 병변으로 의료기관에서 진료를 받기 시작하였고, 2009. 1.경부터 2010. 10.경까지 사이에는 7회에 걸쳐')
# Out:
# [따르면, 원고는 다음과 같이 B로부터 폭행당한 경위를 설명하고 있다. “술에 취한 B가... 더보기 ... 있다고 보아야 한다. 나. 관계법령 산업재해보상보험법 제5조(정의) 이 법에서 사용하는 용어의 뜻은 다음과 같다. 1. “업무상의 재해”란 업무상의 사유에 따른 근로자의 부상질병장해 또는 사망을 말한다. 제49조(추가상병 요양급여의 신청) 업무상의 재해로 요양 중인 근로자는 다음 각 호의 어느 하나에 해당하는 경우에는 그 부상 또는 질병(이하, “추가상병”이라 한다.)에 대한 요양급여를 신청할 수 있다. 1. 그 업무상의 재해로 이미 발생한 부상이나 질병이 추가로 발견되어 요양이 필요한 경우 2. 그 업무상의 재해로 발생한 부상이나 질병이 원인이 되어 새로운 질병이 발생하여 요양이 필요한 경우 다. 인정사실 (1) 이 사건 재해의 내용에 관한 원고의 진술 2012. 2. 17.자 피고 담당공무원 작성의 문답서(갑 제5호증)에 따르면, 원고는 다음과 같이 B로부터 폭행당한 경위를 설명하고 있다. “술에 취한 B가 원고의 목부위에 휴대전화기를 던졌고, 오른손으로 턱을 가격하였다. 주변에서 사람들이 말려서 분을 삭이기 위하여 의자에 앉아 있었는데, B가 다가와 쓰레기통 뚜껑으로 원고를 때렸다. 이후 발인지 손인지 잘 모르겠으나 등을 맞았고, 의자에서 떨어져 땅바닥에 주저앉아 있을 때 발로도 밟힌 것 같다. B로부터 맞은 부위는 목, 오른쪽 턱, 등, 허리 쪽이다. 예전에 허리부위에 수술을 2번 받은 적이 있는데 이 사건 이후 병원에 가 보았더니 옛날 수술부위는 괜찮은데 그 윗부분에 이상이 생겼다고 하였다.” (2) 원고의 이 사건 재해 이전의 치료내역 원고는 2001. 6.경부터 요추부통증 및 제4-5요추-제1천추간 퇴행성 병변으로 의료기관에서 진료를 받기 시작하였고, 2009. 1.경부터 2010. 10.경까지 사이에는 7회에 걸쳐]는 51.05% 확률로 승소이지 않을까 추측해봅니다.^^
